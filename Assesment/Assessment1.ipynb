# %% [markdown]
# # Assessment 1: I can train and deploy a neural network

# %% [markdown]
# At this point, you've worked through a full deep learning workflow. You've loaded a dataset, trained a model, and deployed your model into a simple application. Validate your learning by attempting to replicate that workflow with a new problem.
#
# We've included a dataset which consists of two classes:
#
# 1) Face: Contains images which include the face of a whale
# 2) Not Face: Contains images which do not include the face of a whale.
#
# The dataset is located at ```/dli/data/whale/data/train```.
#
# Your challenge is:
#
# 1) Use [DIGITS](/digits) to train a model to identify *new* whale faces with an accuracy of more than 80%.
#
# 2) Deploy your model by modifying and saving the python application [submission.py](../../../../edit/tasks/task-assessment/task/submission.py) to return the word "whale" if the image contains a whale's face and "not whale" if the image does not.
#
# Resources:
#
# 1) [Train a model](../../task1/task/Train%20a%20Model.ipynb)
# 2) [New Data as a goal](../../task2/task/New%20Data%20as%20a%20Goal.ipynb)
# 3) [Deployment](../../task3/task/Deployment.ipynb)
#
# Suggestions:
#
# - Use empty code blocks to find out any informantion necessary to solve this problem: eg: ```!ls [directorypath] prints the files in a given directory```
# - Executing the first two cells below will run your python script with test images, the first should return "whale" and the second should return "not whale"

# %% [markdown]
# Start in [DIGITS](/digits/).

# %%
# !python submission.py '/dli/data/whale/data/train/face/w_1.jpg' #This should return "whale" at the very bottom of the output.
# Out:
# WARNING: Logging before InitGoogleLogging() is written to STDERR
# I0707 15:13:23.496290   340 upgrade_proto.cpp:66] Attempting to upgrade input file specified using deprecated input fields: /dli/data/digits/20180707-145226-135e/deploy.prototxt
# I0707 15:13:23.496357   340 upgrade_proto.cpp:69] Successfully upgraded file specified using deprecated input fields.
# W0707 15:13:23.496369   340 upgrade_proto.cpp:71] Note that future Caffe releases will only support input layers and not input fields.
# I0707 15:13:23.497277   340 net.cpp:52] Initializing net from parameters:
# state {
#   phase: TEST
# }
# layer {
#   name: "input"
#   type: "Input"
#   top: "data"
#   input_param {
#     shape {
#       dim: 1
#       dim: 3
#       dim: 224
#       dim: 224
#     }
#   }
# }
# layer {
#   name: "conv1/7x7_s2"
#   type: "Convolution"
#   bottom: "data"
#   top: "conv1/7x7_s2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 64
#     pad: 3
#     kernel_size: 7
#     stride: 2
#     weight_filler {
#       type: "xavier"
#       std: 0.1
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "conv1/relu_7x7"
#   type: "ReLU"
#   bottom: "conv1/7x7_s2"
#   top: "conv1/7x7_s2"
# }
# layer {
#   name: "pool1/3x3_s2"
#   type: "Pooling"
#   bottom: "conv1/7x7_s2"
#   top: "pool1/3x3_s2"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "pool1/norm1"
#   type: "LRN"
#   bottom: "pool1/3x3_s2"
#   top: "pool1/norm1"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "conv2/3x3_reduce"
#   type: "Convolution"
#   bottom: "pool1/norm1"
#   top: "conv2/3x3_reduce"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 64
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.1
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "conv2/relu_3x3_reduce"
#   type: "ReLU"
#   bottom: "conv2/3x3_reduce"
#   top: "conv2/3x3_reduce"
# }
# layer {
#   name: "conv2/3x3"
#   type: "Convolution"
#   bottom: "conv2/3x3_reduce"
#   top: "conv2/3x3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 192
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "conv2/relu_3x3"
#   type: "ReLU"
#   bottom: "conv2/3x3"
#   top: "conv2/3x3"
# }
# layer {
#   name: "conv2/norm2"
#   type: "LRN"
#   bottom: "conv2/3x3"
#   top: "conv2/norm2"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool2/3x3_s2"
#   type: "Pooling"
#   bottom: "conv2/norm2"
#   top: "pool2/3x3_s2"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "inception_3a/1x1"
#   type: "Convolution"
#   bottom: "pool2/3x3_s2"
#   top: "inception_3a/1x1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 64
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_3a/relu_1x1"
#   type: "ReLU"
#   bottom: "inception_3a/1x1"
#   top: "inception_3a/1x1"
# }
# layer {
#   name: "inception_3a/3x3_reduce"
#   type: "Convolution"
#   bottom: "pool2/3x3_s2"
#   top: "inception_3a/3x3_reduce"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 96
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.09
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_3a/relu_3x3_reduce"
#   type: "ReLU"
#   bottom: "inception_3a/3x3_reduce"
#   top: "inception_3a/3x3_reduce"
# }
# layer {
#   name: "inception_3a/3x3"
#   type: "Convolution"
#   bottom: "inception_3a/3x3_reduce"
#   top: "inception_3a/3x3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 128
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_3a/relu_3x3"
#   type: "ReLU"
#   bottom: "inception_3a/3x3"
#   top: "inception_3a/3x3"
# }
# layer {
#   name: "inception_3a/5x5_reduce"
#   type: "Convolution"
#   bottom: "pool2/3x3_s2"
#   top: "inception_3a/5x5_reduce"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 16
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.2
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_3a/relu_5x5_reduce"
#   type: "ReLU"
#   bottom: "inception_3a/5x5_reduce"
#   top: "inception_3a/5x5_reduce"
# }
# layer {
#   name: "inception_3a/5x5"
#   type: "Convolution"
#   bottom: "inception_3a/5x5_reduce"
#   top: "inception_3a/5x5"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 32
#     pad: 2
#     kernel_size: 5
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_3a/relu_5x5"
#   type: "ReLU"
#   bottom: "inception_3a/5x5"
#   top: "inception_3a/5x5"
# }
# layer {
#   name: "inception_3a/pool"
#   type: "Pooling"
#   bottom: "pool2/3x3_s2"
#   top: "inception_3a/pool"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 1
#     pad: 1
#   }
# }
# layer {
#   name: "inception_3a/pool_proj"
#   type: "Convolution"
#   bottom: "inception_3a/pool"
#   top: "inception_3a/pool_proj"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 32
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.1
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_3a/relu_pool_proj"
#   type: "ReLU"
#   bottom: "inception_3a/pool_proj"
#   top: "inception_3a/pool_proj"
# }
# layer {
#   name: "inception_3a/output"
#   type: "Concat"
#   bottom: "inception_3a/1x1"
#   bottom: "inception_3a/3x3"
#   bottom: "inception_3a/5x5"
#   bottom: "inception_3a/pool_proj"
#   top: "inception_3a/output"
# }
# layer {
#   name: "inception_3b/1x1"
#   type: "Convolution"
#   bottom: "inception_3a/output"
#   top: "inception_3b/1x1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 128
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_3b/relu_1x1"
#   type: "ReLU"
#   bottom: "inception_3b/1x1"
#   top: "inception_3b/1x1"
# }
# layer {
#   name: "inception_3b/3x3_reduce"
#   type: "Convolution"
#   bottom: "inception_3a/output"
#   top: "inception_3b/3x3_reduce"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 128
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.09
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_3b/relu_3x3_reduce"
#   type: "ReLU"
#   bottom: "inception_3b/3x3_reduce"
#   top: "inception_3b/3x3_reduce"
# }
# layer {
#   name: "inception_3b/3x3"
#   type: "Convolution"
#   bottom: "inception_3b/3x3_reduce"
#   top: "inception_3b/3x3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 192
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_3b/relu_3x3"
#   type: "ReLU"
#   bottom: "inception_3b/3x3"
#   top: "inception_3b/3x3"
# }
# layer {
#   name: "inception_3b/5x5_reduce"
#   type: "Convolution"
#   bottom: "inception_3a/output"
#   top: "inception_3b/5x5_reduce"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 32
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.2
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_3b/relu_5x5_reduce"
#   type: "ReLU"
#   bottom: "inception_3b/5x5_reduce"
#   top: "inception_3b/5x5_reduce"
# }
# layer {
#   name: "inception_3b/5x5"
#   type: "Convolution"
#   bottom: "inception_3b/5x5_reduce"
#   top: "inception_3b/5x5"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 96
#     pad: 2
#     kernel_size: 5
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_3b/relu_5x5"
#   type: "ReLU"
#   bottom: "inception_3b/5x5"
#   top: "inception_3b/5x5"
# }
# layer {
#   name: "inception_3b/pool"
#   type: "Pooling"
#   bottom: "inception_3a/output"
#   top: "inception_3b/pool"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 1
#     pad: 1
#   }
# }
# layer {
#   name: "inception_3b/pool_proj"
#   type: "Convolution"
#   bottom: "inception_3b/pool"
#   top: "inception_3b/pool_proj"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 64
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.1
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_3b/relu_pool_proj"
#   type: "ReLU"
#   bottom: "inception_3b/pool_proj"
#   top: "inception_3b/pool_proj"
# }
# layer {
#   name: "inception_3b/output"
#   type: "Concat"
#   bottom: "inception_3b/1x1"
#   bottom: "inception_3b/3x3"
#   bottom: "inception_3b/5x5"
#   bottom: "inception_3b/pool_proj"
#   top: "inception_3b/output"
# }
# layer {
#   name: "pool3/3x3_s2"
#   type: "Pooling"
#   bottom: "inception_3b/output"
#   top: "pool3/3x3_s2"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "inception_4a/1x1"
#   type: "Convolution"
#   bottom: "pool3/3x3_s2"
#   top: "inception_4a/1x1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 192
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4a/relu_1x1"
#   type: "ReLU"
#   bottom: "inception_4a/1x1"
#   top: "inception_4a/1x1"
# }
# layer {
#   name: "inception_4a/3x3_reduce"
#   type: "Convolution"
#   bottom: "pool3/3x3_s2"
#   top: "inception_4a/3x3_reduce"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 96
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.09
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4a/relu_3x3_reduce"
#   type: "ReLU"
#   bottom: "inception_4a/3x3_reduce"
#   top: "inception_4a/3x3_reduce"
# }
# layer {
#   name: "inception_4a/3x3"
#   type: "Convolution"
#   bottom: "inception_4a/3x3_reduce"
#   top: "inception_4a/3x3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 208
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4a/relu_3x3"
#   type: "ReLU"
#   bottom: "inception_4a/3x3"
#   top: "inception_4a/3x3"
# }
# layer {
#   name: "inception_4a/5x5_reduce"
#   type: "Convolution"
#   bottom: "pool3/3x3_s2"
#   top: "inception_4a/5x5_reduce"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 16
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.2
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4a/relu_5x5_reduce"
#   type: "ReLU"
#   bottom: "inception_4a/5x5_reduce"
#   top: "inception_4a/5x5_reduce"
# }
# layer {
#   name: "inception_4a/5x5"
#   type: "Convolution"
#   bottom: "inception_4a/5x5_reduce"
#   top: "inception_4a/5x5"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 48
#     pad: 2
#     kernel_size: 5
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4a/relu_5x5"
#   type: "ReLU"
#   bottom: "inception_4a/5x5"
#   top: "inception_4a/5x5"
# }
# layer {
#   name: "inception_4a/pool"
#   type: "Pooling"
#   bottom: "pool3/3x3_s2"
#   top: "inception_4a/pool"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 1
#     pad: 1
#   }
# }
# layer {
#   name: "inception_4a/pool_proj"
#   type: "Convolution"
#   bottom: "inception_4a/pool"
#   top: "inception_4a/pool_proj"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 64
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.1
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4a/relu_pool_proj"
#   type: "ReLU"
#   bottom: "inception_4a/pool_proj"
#   top: "inception_4a/pool_proj"
# }
# layer {
#   name: "inception_4a/output"
#   type: "Concat"
#   bottom: "inception_4a/1x1"
#   bottom: "inception_4a/3x3"
#   bottom: "inception_4a/5x5"
#   bottom: "inception_4a/pool_proj"
#   top: "inception_4a/output"
# }
# layer {
#   name: "inception_4b/1x1"
#   type: "Convolution"
#   bottom: "inception_4a/output"
#   top: "inception_4b/1x1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 160
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4b/relu_1x1"
#   type: "ReLU"
#   bottom: "inception_4b/1x1"
#   top: "inception_4b/1x1"
# }
# layer {
#   name: "inception_4b/3x3_reduce"
#   type: "Convolution"
#   bottom: "inception_4a/output"
#   top: "inception_4b/3x3_reduce"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 112
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.09
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4b/relu_3x3_reduce"
#   type: "ReLU"
#   bottom: "inception_4b/3x3_reduce"
#   top: "inception_4b/3x3_reduce"
# }
# layer {
#   name: "inception_4b/3x3"
#   type: "Convolution"
#   bottom: "inception_4b/3x3_reduce"
#   top: "inception_4b/3x3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 224
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4b/relu_3x3"
#   type: "ReLU"
#   bottom: "inception_4b/3x3"
#   top: "inception_4b/3x3"
# }
# layer {
#   name: "inception_4b/5x5_reduce"
#   type: "Convolution"
#   bottom: "inception_4a/output"
#   top: "inception_4b/5x5_reduce"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 24
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.2
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4b/relu_5x5_reduce"
#   type: "ReLU"
#   bottom: "inception_4b/5x5_reduce"
#   top: "inception_4b/5x5_reduce"
# }
# layer {
#   name: "inception_4b/5x5"
#   type: "Convolution"
#   bottom: "inception_4b/5x5_reduce"
#   top: "inception_4b/5x5"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 64
#     pad: 2
#     kernel_size: 5
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4b/relu_5x5"
#   type: "ReLU"
#   bottom: "inception_4b/5x5"
#   top: "inception_4b/5x5"
# }
# layer {
#   name: "inception_4b/pool"
#   type: "Pooling"
#   bottom: "inception_4a/output"
#   top: "inception_4b/pool"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 1
#     pad: 1
#   }
# }
# layer {
#   name: "inception_4b/pool_proj"
#   type: "Convolution"
#   bottom: "inception_4b/pool"
#   top: "inception_4b/pool_proj"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 64
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.1
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4b/relu_pool_proj"
#   type: "ReLU"
#   bottom: "inception_4b/pool_proj"
#   top: "inception_4b/pool_proj"
# }
# layer {
#   name: "inception_4b/output"
#   type: "Concat"
#   bottom: "inception_4b/1x1"
#   bottom: "inception_4b/3x3"
#   bottom: "inception_4b/5x5"
#   bottom: "inception_4b/pool_proj"
#   top: "inception_4b/output"
# }
# layer {
#   name: "inception_4c/1x1"
#   type: "Convolution"
#   bottom: "inception_4b/output"
#   top: "inception_4c/1x1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 128
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4c/relu_1x1"
#   type: "ReLU"
#   bottom: "inception_4c/1x1"
#   top: "inception_4c/1x1"
# }
# layer {
#   name: "inception_4c/3x3_reduce"
#   type: "Convolution"
#   bottom: "inception_4b/output"
#   top: "inception_4c/3x3_reduce"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 128
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.09
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4c/relu_3x3_reduce"
#   type: "ReLU"
#   bottom: "inception_4c/3x3_reduce"
#   top: "inception_4c/3x3_reduce"
# }
# layer {
#   name: "inception_4c/3x3"
#   type: "Convolution"
#   bottom: "inception_4c/3x3_reduce"
#   top: "inception_4c/3x3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4c/relu_3x3"
#   type: "ReLU"
#   bottom: "inception_4c/3x3"
#   top: "inception_4c/3x3"
# }
# layer {
#   name: "inception_4c/5x5_reduce"
#   type: "Convolution"
#   bottom: "inception_4b/output"
#   top: "inception_4c/5x5_reduce"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 24
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.2
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4c/relu_5x5_reduce"
#   type: "ReLU"
#   bottom: "inception_4c/5x5_reduce"
#   top: "inception_4c/5x5_reduce"
# }
# layer {
#   name: "inception_4c/5x5"
#   type: "Convolution"
#   bottom: "inception_4c/5x5_reduce"
#   top: "inception_4c/5x5"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 64
#     pad: 2
#     kernel_size: 5
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4c/relu_5x5"
#   type: "ReLU"
#   bottom: "inception_4c/5x5"
#   top: "inception_4c/5x5"
# }
# layer {
#   name: "inception_4c/pool"
#   type: "Pooling"
#   bottom: "inception_4b/output"
#   top: "inception_4c/pool"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 1
#     pad: 1
#   }
# }
# layer {
#   name: "inception_4c/pool_proj"
#   type: "Convolution"
#   bottom: "inception_4c/pool"
#   top: "inception_4c/pool_proj"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 64
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.1
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4c/relu_pool_proj"
#   type: "ReLU"
#   bottom: "inception_4c/pool_proj"
#   top: "inception_4c/pool_proj"
# }
# layer {
#   name: "inception_4c/output"
#   type: "Concat"
#   bottom: "inception_4c/1x1"
#   bottom: "inception_4c/3x3"
#   bottom: "inception_4c/5x5"
#   bottom: "inception_4c/pool_proj"
#   top: "inception_4c/output"
# }
# layer {
#   name: "inception_4d/1x1"
#   type: "Convolution"
#   bottom: "inception_4c/output"
#   top: "inception_4d/1x1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 112
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4d/relu_1x1"
#   type: "ReLU"
#   bottom: "inception_4d/1x1"
#   top: "inception_4d/1x1"
# }
# layer {
#   name: "inception_4d/3x3_reduce"
#   type: "Convolution"
#   bottom: "inception_4c/output"
#   top: "inception_4d/3x3_reduce"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 144
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.09
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4d/relu_3x3_reduce"
#   type: "ReLU"
#   bottom: "inception_4d/3x3_reduce"
#   top: "inception_4d/3x3_reduce"
# }
# layer {
#   name: "inception_4d/3x3"
#   type: "Convolution"
#   bottom: "inception_4d/3x3_reduce"
#   top: "inception_4d/3x3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 288
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4d/relu_3x3"
#   type: "ReLU"
#   bottom: "inception_4d/3x3"
#   top: "inception_4d/3x3"
# }
# layer {
#   name: "inception_4d/5x5_reduce"
#   type: "Convolution"
#   bottom: "inception_4c/output"
#   top: "inception_4d/5x5_reduce"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 32
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.2
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4d/relu_5x5_reduce"
#   type: "ReLU"
#   bottom: "inception_4d/5x5_reduce"
#   top: "inception_4d/5x5_reduce"
# }
# layer {
#   name: "inception_4d/5x5"
#   type: "Convolution"
#   bottom: "inception_4d/5x5_reduce"
#   top: "inception_4d/5x5"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 64
#     pad: 2
#     kernel_size: 5
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4d/relu_5x5"
#   type: "ReLU"
#   bottom: "inception_4d/5x5"
#   top: "inception_4d/5x5"
# }
# layer {
#   name: "inception_4d/pool"
#   type: "Pooling"
#   bottom: "inception_4c/output"
#   top: "inception_4d/pool"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 1
#     pad: 1
#   }
# }
# layer {
#   name: "inception_4d/pool_proj"
#   type: "Convolution"
#   bottom: "inception_4d/pool"
#   top: "inception_4d/pool_proj"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 64
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.1
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4d/relu_pool_proj"
#   type: "ReLU"
#   bottom: "inception_4d/pool_proj"
#   top: "inception_4d/pool_proj"
# }
# layer {
#   name: "inception_4d/output"
#   type: "Concat"
#   bottom: "inception_4d/1x1"
#   bottom: "inception_4d/3x3"
#   bottom: "inception_4d/5x5"
#   bottom: "inception_4d/pool_proj"
#   top: "inception_4d/output"
# }
# layer {
#   name: "inception_4e/1x1"
#   type: "Convolution"
#   bottom: "inception_4d/output"
#   top: "inception_4e/1x1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4e/relu_1x1"
#   type: "ReLU"
#   bottom: "inception_4e/1x1"
#   top: "inception_4e/1x1"
# }
# layer {
#   name: "inception_4e/3x3_reduce"
#   type: "Convolution"
#   bottom: "inception_4d/output"
#   top: "inception_4e/3x3_reduce"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 160
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.09
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4e/relu_3x3_reduce"
#   type: "ReLU"
#   bottom: "inception_4e/3x3_reduce"
#   top: "inception_4e/3x3_reduce"
# }
# layer {
#   name: "inception_4e/3x3"
#   type: "Convolution"
#   bottom: "inception_4e/3x3_reduce"
#   top: "inception_4e/3x3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 320
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4e/relu_3x3"
#   type: "ReLU"
#   bottom: "inception_4e/3x3"
#   top: "inception_4e/3x3"
# }
# layer {
#   name: "inception_4e/5x5_reduce"
#   type: "Convolution"
#   bottom: "inception_4d/output"
#   top: "inception_4e/5x5_reduce"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 32
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.2
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4e/relu_5x5_reduce"
#   type: "ReLU"
#   bottom: "inception_4e/5x5_reduce"
#   top: "inception_4e/5x5_reduce"
# }
# layer {
#   name: "inception_4e/5x5"
#   type: "Convolution"
#   bottom: "inception_4e/5x5_reduce"
#   top: "inception_4e/5x5"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 128
#     pad: 2
#     kernel_size: 5
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4e/relu_5x5"
#   type: "ReLU"
#   bottom: "inception_4e/5x5"
#   top: "inception_4e/5x5"
# }
# layer {
#   name: "inception_4e/pool"
#   type: "Pooling"
#   bottom: "inception_4d/output"
#   top: "inception_4e/pool"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 1
#     pad: 1
#   }
# }
# layer {
#   name: "inception_4e/pool_proj"
#   type: "Convolution"
#   bottom: "inception_4e/pool"
#   top: "inception_4e/pool_proj"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 128
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.1
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4e/relu_pool_proj"
#   type: "ReLU"
#   bottom: "inception_4e/pool_proj"
#   top: "inception_4e/pool_proj"
# }
# layer {
#   name: "inception_4e/output"
#   type: "Concat"
#   bottom: "inception_4e/1x1"
#   bottom: "inception_4e/3x3"
#   bottom: "inception_4e/5x5"
#   bottom: "inception_4e/pool_proj"
#   top: "inception_4e/output"
# }
# layer {
#   name: "pool4/3x3_s2"
#   type: "Pooling"
#   bottom: "inception_4e/output"
#   top: "pool4/3x3_s2"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "inception_5a/1x1"
#   type: "Convolution"
#   bottom: "pool4/3x3_s2"
#   top: "inception_5a/1x1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_5a/relu_1x1"
#   type: "ReLU"
#   bottom: "inception_5a/1x1"
#   top: "inception_5a/1x1"
# }
# layer {
#   name: "inception_5a/3x3_reduce"
#   type: "Convolution"
#   bottom: "pool4/3x3_s2"
#   top: "inception_5a/3x3_reduce"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 160
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.09
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_5a/relu_3x3_reduce"
#   type: "ReLU"
#   bottom: "inception_5a/3x3_reduce"
#   top: "inception_5a/3x3_reduce"
# }
# layer {
#   name: "inception_5a/3x3"
#   type: "Convolution"
#   bottom: "inception_5a/3x3_reduce"
#   top: "inception_5a/3x3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 320
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_5a/relu_3x3"
#   type: "ReLU"
#   bottom: "inception_5a/3x3"
#   top: "inception_5a/3x3"
# }
# layer {
#   name: "inception_5a/5x5_reduce"
#   type: "Convolution"
#   bottom: "pool4/3x3_s2"
#   top: "inception_5a/5x5_reduce"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 32
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.2
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   na
# I0707 15:13:23.502056   340 layer_factory.hpp:77] Creating layer input
# I0707 15:13:23.502089   340 net.cpp:94] Creating Layer input
# I0707 15:13:23.502101   340 net.cpp:409] input -> data
# I0707 15:13:23.502800   340 net.cpp:144] Setting up input
# I0707 15:13:23.502825   340 net.cpp:151] Top shape: 1 3 224 224 (150528)
# I0707 15:13:23.502835   340 net.cpp:159] Memory required for data: 602112
# I0707 15:13:23.502849   340 layer_factory.hpp:77] Creating layer conv1/7x7_s2
# I0707 15:13:23.502876   340 net.cpp:94] Creating Layer conv1/7x7_s2
# I0707 15:13:23.502887   340 net.cpp:435] conv1/7x7_s2 <- data
# I0707 15:13:23.502898   340 net.cpp:409] conv1/7x7_s2 -> conv1/7x7_s2
# I0707 15:13:23.504117   340 net.cpp:144] Setting up conv1/7x7_s2
# I0707 15:13:23.504139   340 net.cpp:151] Top shape: 1 64 112 112 (802816)
# I0707 15:13:23.504150   340 net.cpp:159] Memory required for data: 3813376
# I0707 15:13:23.504173   340 layer_factory.hpp:77] Creating layer conv1/relu_7x7
# I0707 15:13:23.504189   340 net.cpp:94] Creating Layer conv1/relu_7x7
# I0707 15:13:23.504197   340 net.cpp:435] conv1/relu_7x7 <- conv1/7x7_s2
# I0707 15:13:23.504210   340 net.cpp:396] conv1/relu_7x7 -> conv1/7x7_s2 (in-place)
# I0707 15:13:23.504226   340 net.cpp:144] Setting up conv1/relu_7x7
# I0707 15:13:23.504236   340 net.cpp:151] Top shape: 1 64 112 112 (802816)
# I0707 15:13:23.504245   340 net.cpp:159] Memory required for data: 7024640
# I0707 15:13:23.504251   340 layer_factory.hpp:77] Creating layer pool1/3x3_s2
# I0707 15:13:23.504261   340 net.cpp:94] Creating Layer pool1/3x3_s2
# I0707 15:13:23.504269   340 net.cpp:435] pool1/3x3_s2 <- conv1/7x7_s2
# I0707 15:13:23.504283   340 net.cpp:409] pool1/3x3_s2 -> pool1/3x3_s2
# I0707 15:13:23.504338   340 net.cpp:144] Setting up pool1/3x3_s2
# I0707 15:13:23.504354   340 net.cpp:151] Top shape: 1 64 56 56 (200704)
# I0707 15:13:23.504366   340 net.cpp:159] Memory required for data: 7827456
# I0707 15:13:23.504379   340 layer_factory.hpp:77] Creating layer pool1/norm1
# I0707 15:13:23.504395   340 net.cpp:94] Creating Layer pool1/norm1
# I0707 15:13:23.504405   340 net.cpp:435] pool1/norm1 <- pool1/3x3_s2
# I0707 15:13:23.504421   340 net.cpp:409] pool1/norm1 -> pool1/norm1
# I0707 15:13:23.504498   340 net.cpp:144] Setting up pool1/norm1
# I0707 15:13:23.504514   340 net.cpp:151] Top shape: 1 64 56 56 (200704)
# I0707 15:13:23.504526   340 net.cpp:159] Memory required for data: 8630272
# I0707 15:13:23.504539   340 layer_factory.hpp:77] Creating layer conv2/3x3_reduce
# I0707 15:13:23.504559   340 net.cpp:94] Creating Layer conv2/3x3_reduce
# I0707 15:13:23.504568   340 net.cpp:435] conv2/3x3_reduce <- pool1/norm1
# I0707 15:13:23.504587   340 net.cpp:409] conv2/3x3_reduce -> conv2/3x3_reduce
# I0707 15:13:23.505409   340 net.cpp:144] Setting up conv2/3x3_reduce
# I0707 15:13:23.505436   340 net.cpp:151] Top shape: 1 64 56 56 (200704)
# I0707 15:13:23.505450   340 net.cpp:159] Memory required for data: 9433088
# I0707 15:13:23.505468   340 layer_factory.hpp:77] Creating layer conv2/relu_3x3_reduce
# I0707 15:13:23.505481   340 net.cpp:94] Creating Layer conv2/relu_3x3_reduce
# I0707 15:13:23.505489   340 net.cpp:435] conv2/relu_3x3_reduce <- conv2/3x3_reduce
# I0707 15:13:23.505501   340 net.cpp:396] conv2/relu_3x3_reduce -> conv2/3x3_reduce (in-place)
# I0707 15:13:23.505515   340 net.cpp:144] Setting up conv2/relu_3x3_reduce
# I0707 15:13:23.505525   340 net.cpp:151] Top shape: 1 64 56 56 (200704)
# I0707 15:13:23.505534   340 net.cpp:159] Memory required for data: 10235904
# I0707 15:13:23.505549   340 layer_factory.hpp:77] Creating layer conv2/3x3
# I0707 15:13:23.505571   340 net.cpp:94] Creating Layer conv2/3x3
# I0707 15:13:23.505581   340 net.cpp:435] conv2/3x3 <- conv2/3x3_reduce
# I0707 15:13:23.505595   340 net.cpp:409] conv2/3x3 -> conv2/3x3
# I0707 15:13:23.506994   340 net.cpp:144] Setting up conv2/3x3
# I0707 15:13:23.507016   340 net.cpp:151] Top shape: 1 192 56 56 (602112)
# I0707 15:13:23.507026   340 net.cpp:159] Memory required for data: 12644352
# I0707 15:13:23.507047   340 layer_factory.hpp:77] Creating layer conv2/relu_3x3
# I0707 15:13:23.507064   340 net.cpp:94] Creating Layer conv2/relu_3x3
# I0707 15:13:23.507076   340 net.cpp:435] conv2/relu_3x3 <- conv2/3x3
# I0707 15:13:23.507086   340 net.cpp:396] conv2/relu_3x3 -> conv2/3x3 (in-place)
# I0707 15:13:23.507099   340 net.cpp:144] Setting up conv2/relu_3x3
# I0707 15:13:23.507109   340 net.cpp:151] Top shape: 1 192 56 56 (602112)
# I0707 15:13:23.507118   340 net.cpp:159] Memory required for data: 15052800
# I0707 15:13:23.507128   340 layer_factory.hpp:77] Creating layer conv2/norm2
# I0707 15:13:23.507145   340 net.cpp:94] Creating Layer conv2/norm2
# I0707 15:13:23.507155   340 net.cpp:435] conv2/norm2 <- conv2/3x3
# I0707 15:13:23.507166   340 net.cpp:409] conv2/norm2 -> conv2/norm2
# I0707 15:13:23.507212   340 net.cpp:144] Setting up conv2/norm2
# I0707 15:13:23.507225   340 net.cpp:151] Top shape: 1 192 56 56 (602112)
# I0707 15:13:23.507233   340 net.cpp:159] Memory required for data: 17461248
# I0707 15:13:23.507242   340 layer_factory.hpp:77] Creating layer pool2/3x3_s2
# I0707 15:13:23.507249   340 net.cpp:94] Creating Layer pool2/3x3_s2
# I0707 15:13:23.507257   340 net.cpp:435] pool2/3x3_s2 <- conv2/norm2
# I0707 15:13:23.507266   340 net.cpp:409] pool2/3x3_s2 -> pool2/3x3_s2
# I0707 15:13:23.507305   340 net.cpp:144] Setting up pool2/3x3_s2
# I0707 15:13:23.507318   340 net.cpp:151] Top shape: 1 192 28 28 (150528)
# I0707 15:13:23.507321   340 net.cpp:159] Memory required for data: 18063360
# I0707 15:13:23.507330   340 layer_factory.hpp:77] Creating layer pool2/3x3_s2_pool2/3x3_s2_0_split
# I0707 15:13:23.507338   340 net.cpp:94] Creating Layer pool2/3x3_s2_pool2/3x3_s2_0_split
# I0707 15:13:23.507346   340 net.cpp:435] pool2/3x3_s2_pool2/3x3_s2_0_split <- pool2/3x3_s2
# I0707 15:13:23.507354   340 net.cpp:409] pool2/3x3_s2_pool2/3x3_s2_0_split -> pool2/3x3_s2_pool2/3x3_s2_0_split_0
# I0707 15:13:23.507366   340 net.cpp:409] pool2/3x3_s2_pool2/3x3_s2_0_split -> pool2/3x3_s2_pool2/3x3_s2_0_split_1
# I0707 15:13:23.507381   340 net.cpp:409] pool2/3x3_s2_pool2/3x3_s2_0_split -> pool2/3x3_s2_pool2/3x3_s2_0_split_2
# I0707 15:13:23.507392   340 net.cpp:409] pool2/3x3_s2_pool2/3x3_s2_0_split -> pool2/3x3_s2_pool2/3x3_s2_0_split_3
# I0707 15:13:23.507448   340 net.cpp:144] Setting up pool2/3x3_s2_pool2/3x3_s2_0_split
# I0707 15:13:23.507460   340 net.cpp:151] Top shape: 1 192 28 28 (150528)
# I0707 15:13:23.507472   340 net.cpp:151] Top shape: 1 192 28 28 (150528)
# I0707 15:13:23.507484   340 net.cpp:151] Top shape: 1 192 28 28 (150528)
# I0707 15:13:23.507496   340 net.cpp:151] Top shape: 1 192 28 28 (150528)
# I0707 15:13:23.507504   340 net.cpp:159] Memory required for data: 20471808
# I0707 15:13:23.507517   340 layer_factory.hpp:77] Creating layer inception_3a/1x1
# I0707 15:13:23.507539   340 net.cpp:94] Creating Layer inception_3a/1x1
# I0707 15:13:23.507550   340 net.cpp:435] inception_3a/1x1 <- pool2/3x3_s2_pool2/3x3_s2_0_split_0
# I0707 15:13:23.507566   340 net.cpp:409] inception_3a/1x1 -> inception_3a/1x1
# I0707 15:13:23.508412   340 net.cpp:144] Setting up inception_3a/1x1
# I0707 15:13:23.508437   340 net.cpp:151] Top shape: 1 64 28 28 (50176)
# I0707 15:13:23.508446   340 net.cpp:159] Memory required for data: 20672512
# I0707 15:13:23.508479   340 layer_factory.hpp:77] Creating layer inception_3a/relu_1x1
# I0707 15:13:23.508497   340 net.cpp:94] Creating Layer inception_3a/relu_1x1
# I0707 15:13:23.508510   340 net.cpp:435] inception_3a/relu_1x1 <- inception_3a/1x1
# I0707 15:13:23.508529   340 net.cpp:396] inception_3a/relu_1x1 -> inception_3a/1x1 (in-place)
# I0707 15:13:23.508548   340 net.cpp:144] Setting up inception_3a/relu_1x1
# I0707 15:13:23.508563   340 net.cpp:151] Top shape: 1 64 28 28 (50176)
# I0707 15:13:23.508574   340 net.cpp:159] Memory required for data: 20873216
# I0707 15:13:23.508585   340 layer_factory.hpp:77] Creating layer inception_3a/3x3_reduce
# I0707 15:13:23.508606   340 net.cpp:94] Creating Layer inception_3a/3x3_reduce
# I0707 15:13:23.508618   340 net.cpp:435] inception_3a/3x3_reduce <- pool2/3x3_s2_pool2/3x3_s2_0_split_1
# I0707 15:13:23.508635   340 net.cpp:409] inception_3a/3x3_reduce -> inception_3a/3x3_reduce
# I0707 15:13:23.509549   340 net.cpp:144] Setting up inception_3a/3x3_reduce
# I0707 15:13:23.509577   340 net.cpp:151] Top shape: 1 96 28 28 (75264)
# I0707 15:13:23.509590   340 net.cpp:159] Memory required for data: 21174272
# I0707 15:13:23.509613   340 layer_factory.hpp:77] Creating layer inception_3a/relu_3x3_reduce
# I0707 15:13:23.509627   340 net.cpp:94] Creating Layer inception_3a/relu_3x3_reduce
# I0707 15:13:23.509639   340 net.cpp:435] inception_3a/relu_3x3_reduce <- inception_3a/3x3_reduce
# I0707 15:13:23.509655   340 net.cpp:396] inception_3a/relu_3x3_reduce -> inception_3a/3x3_reduce (in-place)
# I0707 15:13:23.509676   340 net.cpp:144] Setting up inception_3a/relu_3x3_reduce
# I0707 15:13:23.509690   340 net.cpp:151] Top shape: 1 96 28 28 (75264)
# I0707 15:13:23.509701   340 net.cpp:159] Memory required for data: 21475328
# I0707 15:13:23.509713   340 layer_factory.hpp:77] Creating layer inception_3a/3x3
# I0707 15:13:23.509737   340 net.cpp:94] Creating Layer inception_3a/3x3
# I0707 15:13:23.509748   340 net.cpp:435] inception_3a/3x3 <- inception_3a/3x3_reduce
# I0707 15:13:23.509768   340 net.cpp:409] inception_3a/3x3 -> inception_3a/3x3
# I0707 15:13:23.510581   340 net.cpp:144] Setting up inception_3a/3x3
# I0707 15:13:23.510598   340 net.cpp:151] Top shape: 1 128 28 28 (100352)
# I0707 15:13:23.510607   340 net.cpp:159] Memory required for data: 21876736
# I0707 15:13:23.510622   340 layer_factory.hpp:77] Creating layer inception_3a/relu_3x3
# I0707 15:13:23.510639   340 net.cpp:94] Creating Layer inception_3a/relu_3x3
# I0707 15:13:23.510650   340 net.cpp:435] inception_3a/relu_3x3 <- inception_3a/3x3
# I0707 15:13:23.510666   340 net.cpp:396] inception_3a/relu_3x3 -> inception_3a/3x3 (in-place)
# I0707 15:13:23.510684   340 net.cpp:144] Setting up inception_3a/relu_3x3
# I0707 15:13:23.510696   340 net.cpp:151] Top shape: 1 128 28 28 (100352)
# I0707 15:13:23.510709   340 net.cpp:159] Memory required for data: 22278144
# I0707 15:13:23.510720   340 layer_factory.hpp:77] Creating layer inception_3a/5x5_reduce
# I0707 15:13:23.510740   340 net.cpp:94] Creating Layer inception_3a/5x5_reduce
# I0707 15:13:23.510751   340 net.cpp:435] inception_3a/5x5_reduce <- pool2/3x3_s2_pool2/3x3_s2_0_split_2
# I0707 15:13:23.510771   340 net.cpp:409] inception_3a/5x5_reduce -> inception_3a/5x5_reduce
# I0707 15:13:23.511010   340 net.cpp:144] Setting up inception_3a/5x5_reduce
# I0707 15:13:23.511029   340 net.cpp:151] Top shape: 1 16 28 28 (12544)
# I0707 15:13:23.511041   340 net.cpp:159] Memory required for data: 22328320
# I0707 15:13:23.511056   340 layer_factory.hpp:77] Creating layer inception_3a/relu_5x5_reduce
# I0707 15:13:23.511070   340 net.cpp:94] Creating Layer inception_3a/relu_5x5_reduce
# I0707 15:13:23.511085   340 net.cpp:435] inception_3a/relu_5x5_reduce <- inception_3a/5x5_reduce
# I0707 15:13:23.511101   340 net.cpp:396] inception_3a/relu_5x5_reduce -> inception_3a/5x5_reduce (in-place)
# I0707 15:13:23.511116   340 net.cpp:144] Setting up inception_3a/relu_5x5_reduce
# I0707 15:13:23.511131   340 net.cpp:151] Top shape: 1 16 28 28 (12544)
# I0707 15:13:23.511142   340 net.cpp:159] Memory required for data: 22378496
# I0707 15:13:23.511153   340 layer_factory.hpp:77] Creating layer inception_3a/5x5
# I0707 15:13:23.511173   340 net.cpp:94] Creating Layer inception_3a/5x5
# I0707 15:13:23.511184   340 net.cpp:435] inception_3a/5x5 <- inception_3a/5x5_reduce
# I0707 15:13:23.511204   340 net.cpp:409] inception_3a/5x5 -> inception_3a/5x5
# I0707 15:13:23.511499   340 net.cpp:144] Setting up inception_3a/5x5
# I0707 15:13:23.511518   340 net.cpp:151] Top shape: 1 32 28 28 (25088)
# I0707 15:13:23.511529   340 net.cpp:159] Memory required for data: 22478848
# I0707 15:13:23.511545   340 layer_factory.hpp:77] Creating layer inception_3a/relu_5x5
# I0707 15:13:23.511560   340 net.cpp:94] Creating Layer inception_3a/relu_5x5
# I0707 15:13:23.511572   340 net.cpp:435] inception_3a/relu_5x5 <- inception_3a/5x5
# I0707 15:13:23.511590   340 net.cpp:396] inception_3a/relu_5x5 -> inception_3a/5x5 (in-place)
# I0707 15:13:23.511606   340 net.cpp:144] Setting up inception_3a/relu_5x5
# I0707 15:13:23.511620   340 net.cpp:151] Top shape: 1 32 28 28 (25088)
# I0707 15:13:23.511632   340 net.cpp:159] Memory required for data: 22579200
# I0707 15:13:23.511644   340 layer_factory.hpp:77] Creating layer inception_3a/pool
# I0707 15:13:23.511659   340 net.cpp:94] Creating Layer inception_3a/pool
# I0707 15:13:23.511670   340 net.cpp:435] inception_3a/pool <- pool2/3x3_s2_pool2/3x3_s2_0_split_3
# I0707 15:13:23.511688   340 net.cpp:409] inception_3a/pool -> inception_3a/pool
# I0707 15:13:23.511736   340 net.cpp:144] Setting up inception_3a/pool
# I0707 15:13:23.511752   340 net.cpp:151] Top shape: 1 192 28 28 (150528)
# I0707 15:13:23.511765   340 net.cpp:159] Memory required for data: 23181312
# I0707 15:13:23.511773   340 layer_factory.hpp:77] Creating layer inception_3a/pool_proj
# I0707 15:13:23.511792   340 net.cpp:94] Creating Layer inception_3a/pool_proj
# I0707 15:13:23.511803   340 net.cpp:435] inception_3a/pool_proj <- inception_3a/pool
# I0707 15:13:23.511819   340 net.cpp:409] inception_3a/pool_proj -> inception_3a/pool_proj
# I0707 15:13:23.512065   340 net.cpp:144] Setting up inception_3a/pool_proj
# I0707 15:13:23.512085   340 net.cpp:151] Top shape: 1 32 28 28 (25088)
# I0707 15:13:23.512097   340 net.cpp:159] Memory required for data: 23281664
# I0707 15:13:23.512117   340 layer_factory.hpp:77] Creating layer inception_3a/relu_pool_proj
# I0707 15:13:23.512130   340 net.cpp:94] Creating Layer inception_3a/relu_pool_proj
# I0707 15:13:23.512142   340 net.cpp:435] inception_3a/relu_pool_proj <- inception_3a/pool_proj
# I0707 15:13:23.512161   340 net.cpp:396] inception_3a/relu_pool_proj -> inception_3a/pool_proj (in-place)
# I0707 15:13:23.512176   340 net.cpp:144] Setting up inception_3a/relu_pool_proj
# I0707 15:13:23.512189   340 net.cpp:151] Top shape: 1 32 28 28 (25088)
# I0707 15:13:23.512202   340 net.cpp:159] Memory required for data: 23382016
# I0707 15:13:23.512212   340 layer_factory.hpp:77] Creating layer inception_3a/output
# I0707 15:13:23.512233   340 net.cpp:94] Creating Layer inception_3a/output
# I0707 15:13:23.512243   340 net.cpp:435] inception_3a/output <- inception_3a/1x1
# I0707 15:13:23.512256   340 net.cpp:435] inception_3a/output <- inception_3a/3x3
# I0707 15:13:23.512269   340 net.cpp:435] inception_3a/output <- inception_3a/5x5
# I0707 15:13:23.512281   340 net.cpp:435] inception_3a/output <- inception_3a/pool_proj
# I0707 15:13:23.512298   340 net.cpp:409] inception_3a/output -> inception_3a/output
# I0707 15:13:23.512334   340 net.cpp:144] Setting up inception_3a/output
# I0707 15:13:23.512348   340 net.cpp:151] Top shape: 1 256 28 28 (200704)
# I0707 15:13:23.512361   340 net.cpp:159] Memory required for data: 24184832
# I0707 15:13:23.512372   340 layer_factory.hpp:77] Creating layer inception_3a/output_inception_3a/output_0_split
# I0707 15:13:23.512389   340 net.cpp:94] Creating Layer inception_3a/output_inception_3a/output_0_split
# I0707 15:13:23.512401   340 net.cpp:435] inception_3a/output_inception_3a/output_0_split <- inception_3a/output
# I0707 15:13:23.512419   340 net.cpp:409] inception_3a/output_inception_3a/output_0_split -> inception_3a/output_inception_3a/output_0_split_0
# I0707 15:13:23.512436   340 net.cpp:409] inception_3a/output_inception_3a/output_0_split -> inception_3a/output_inception_3a/output_0_split_1
# I0707 15:13:23.512452   340 net.cpp:409] inception_3a/output_inception_3a/output_0_split -> inception_3a/output_inception_3a/output_0_split_2
# I0707 15:13:23.512491   340 net.cpp:409] inception_3a/output_inception_3a/output_0_split -> inception_3a/output_inception_3a/output_0_split_3
# I0707 15:13:23.512560   340 net.cpp:144] Setting up inception_3a/output_inception_3a/output_0_split
# I0707 15:13:23.512575   340 net.cpp:151] Top shape: 1 256 28 28 (200704)
# I0707 15:13:23.512589   340 net.cpp:151] Top shape: 1 256 28 28 (200704)
# I0707 15:13:23.512603   340 net.cpp:151] Top shape: 1 256 28 28 (200704)
# I0707 15:13:23.512615   340 net.cpp:151] Top shape: 1 256 28 28 (200704)
# I0707 15:13:23.512626   340 net.cpp:159] Memory required for data: 27396096
# I0707 15:13:23.512637   340 layer_factory.hpp:77] Creating layer inception_3b/1x1
# I0707 15:13:23.512660   340 net.cpp:94] Creating Layer inception_3b/1x1
# I0707 15:13:23.512671   340 net.cpp:435] inception_3b/1x1 <- inception_3a/output_inception_3a/output_0_split_0
# I0707 15:13:23.512691   340 net.cpp:409] inception_3b/1x1 -> inception_3b/1x1
# I0707 15:13:23.513080   340 net.cpp:144] Setting up inception_3b/1x1
# I0707 15:13:23.513100   340 net.cpp:151] Top shape: 1 128 28 28 (100352)
# I0707 15:13:23.513113   340 net.cpp:159] Memory required for data: 27797504
# I0707 15:13:23.513130   340 layer_factory.hpp:77] Creating layer inception_3b/relu_1x1
# I0707 15:13:23.513144   340 net.cpp:94] Creating Layer inception_3b/relu_1x1
# I0707 15:13:23.513157   340 net.cpp:435] inception_3b/relu_1x1 <- inception_3b/1x1
# I0707 15:13:23.513173   340 net.cpp:396] inception_3b/relu_1x1 -> inception_3b/1x1 (in-place)
# I0707 15:13:23.513190   340 net.cpp:144] Setting up inception_3b/relu_1x1
# I0707 15:13:23.513203   340 net.cpp:151] Top shape: 1 128 28 28 (100352)
# I0707 15:13:23.513214   340 net.cpp:159] Memory required for data: 28198912
# I0707 15:13:23.513226   340 layer_factory.hpp:77] Creating layer inception_3b/3x3_reduce
# ...
# I0707 15:13:23.584487   340 net.cpp:222] inception_5b/relu_5x5 does not need backward computation.
# I0707 15:13:23.584496   340 net.cpp:222] inception_5b/5x5 does not need backward computation.
# I0707 15:13:23.584501   340 net.cpp:222] inception_5b/relu_5x5_reduce does not need backward computation.
# I0707 15:13:23.584511   340 net.cpp:222] inception_5b/5x5_reduce does not need backward computation.
# I0707 15:13:23.584516   340 net.cpp:222] inception_5b/relu_3x3 does not need backward computation.
# I0707 15:13:23.584524   340 net.cpp:222] inception_5b/3x3 does not need backward computation.
# I0707 15:13:23.584528   340 net.cpp:222] inception_5b/relu_3x3_reduce does not need backward computation.
# I0707 15:13:23.584537   340 net.cpp:222] inception_5b/3x3_reduce does not need backward computation.
# I0707 15:13:23.584542   340 net.cpp:222] inception_5b/relu_1x1 does not need backward computation.
# I0707 15:13:23.584552   340 net.cpp:222] inception_5b/1x1 does not need backward computation.
# I0707 15:13:23.584556   340 net.cpp:222] inception_5a/output_inception_5a/output_0_split does not need backward computation.
# I0707 15:13:23.584564   340 net.cpp:222] inception_5a/output does not need backward computation.
# I0707 15:13:23.584575   340 net.cpp:222] inception_5a/relu_pool_proj does not need backward computation.
# I0707 15:13:23.584584   340 net.cpp:222] inception_5a/pool_proj does not need backward computation.
# I0707 15:13:23.584594   340 net.cpp:222] inception_5a/pool does not need backward computation.
# I0707 15:13:23.584604   340 net.cpp:222] inception_5a/relu_5x5 does not need backward computation.
# I0707 15:13:23.584611   340 net.cpp:222] inception_5a/5x5 does not need backward computation.
# I0707 15:13:23.584621   340 net.cpp:222] inception_5a/relu_5x5_reduce does not need backward computation.
# I0707 15:13:23.584630   340 net.cpp:222] inception_5a/5x5_reduce does not need backward computation.
# I0707 15:13:23.584640   340 net.cpp:222] inception_5a/relu_3x3 does not need backward computation.
# I0707 15:13:23.584648   340 net.cpp:222] inception_5a/3x3 does not need backward computation.
# I0707 15:13:23.584657   340 net.cpp:222] inception_5a/relu_3x3_reduce does not need backward computation.
# I0707 15:13:23.584666   340 net.cpp:222] inception_5a/3x3_reduce does not need backward computation.
# I0707 15:13:23.584681   340 net.cpp:222] inception_5a/relu_1x1 does not need backward computation.
# I0707 15:13:23.584694   340 net.cpp:222] inception_5a/1x1 does not need backward computation.
# I0707 15:13:23.584709   340 net.cpp:222] pool4/3x3_s2_pool4/3x3_s2_0_split does not need backward computation.
# I0707 15:13:23.584720   340 net.cpp:222] pool4/3x3_s2 does not need backward computation.
# I0707 15:13:23.584729   340 net.cpp:222] inception_4e/output does not need backward computation.
# I0707 15:13:23.584739   340 net.cpp:222] inception_4e/relu_pool_proj does not need backward computation.
# I0707 15:13:23.584748   340 net.cpp:222] inception_4e/pool_proj does not need backward computation.
# I0707 15:13:23.584755   340 net.cpp:222] inception_4e/pool does not need backward computation.
# I0707 15:13:23.584765   340 net.cpp:222] inception_4e/relu_5x5 does not need backward computation.
# I0707 15:13:23.584769   340 net.cpp:222] inception_4e/5x5 does not need backward computation.
# I0707 15:13:23.584779   340 net.cpp:222] inception_4e/relu_5x5_reduce does not need backward computation.
# I0707 15:13:23.584782   340 net.cpp:222] inception_4e/5x5_reduce does not need backward computation.
# I0707 15:13:23.584792   340 net.cpp:222] inception_4e/relu_3x3 does not need backward computation.
# I0707 15:13:23.584805   340 net.cpp:222] inception_4e/3x3 does not need backward computation.
# I0707 15:13:23.584816   340 net.cpp:222] inception_4e/relu_3x3_reduce does not need backward computation.
# I0707 15:13:23.584832   340 net.cpp:222] inception_4e/3x3_reduce does not need backward computation.
# I0707 15:13:23.584846   340 net.cpp:222] inception_4e/relu_1x1 does not need backward computation.
# I0707 15:13:23.584854   340 net.cpp:222] inception_4e/1x1 does not need backward computation.
# I0707 15:13:23.584864   340 net.cpp:222] inception_4d/output_inception_4d/output_0_split does not need backward computation.
# I0707 15:13:23.584873   340 net.cpp:222] inception_4d/output does not need backward computation.
# I0707 15:13:23.584883   340 net.cpp:222] inception_4d/relu_pool_proj does not need backward computation.
# I0707 15:13:23.584892   340 net.cpp:222] inception_4d/pool_proj does not need backward computation.
# I0707 15:13:23.584903   340 net.cpp:222] inception_4d/pool does not need backward computation.
# I0707 15:13:23.584910   340 net.cpp:222] inception_4d/relu_5x5 does not need backward computation.
# I0707 15:13:23.584919   340 net.cpp:222] inception_4d/5x5 does not need backward computation.
# I0707 15:13:23.584928   340 net.cpp:222] inception_4d/relu_5x5_reduce does not need backward computation.
# I0707 15:13:23.584941   340 net.cpp:222] inception_4d/5x5_reduce does not need backward computation.
# I0707 15:13:23.584954   340 net.cpp:222] inception_4d/relu_3x3 does not need backward computation.
# I0707 15:13:23.584962   340 net.cpp:222] inception_4d/3x3 does not need backward computation.
# I0707 15:13:23.584967   340 net.cpp:222] inception_4d/relu_3x3_reduce does not need backward computation.
# I0707 15:13:23.584975   340 net.cpp:222] inception_4d/3x3_reduce does not need backward computation.
# I0707 15:13:23.584990   340 net.cpp:222] inception_4d/relu_1x1 does not need backward computation.
# I0707 15:13:23.585003   340 net.cpp:222] inception_4d/1x1 does not need backward computation.
# I0707 15:13:23.585012   340 net.cpp:222] inception_4c/output_inception_4c/output_0_split does not need backward computation.
# I0707 15:13:23.585022   340 net.cpp:222] inception_4c/output does not need backward computation.
# I0707 15:13:23.585028   340 net.cpp:222] inception_4c/relu_pool_proj does not need backward computation.
# I0707 15:13:23.585036   340 net.cpp:222] inception_4c/pool_proj does not need backward computation.
# I0707 15:13:23.585041   340 net.cpp:222] inception_4c/pool does not need backward computation.
# I0707 15:13:23.585049   340 net.cpp:222] inception_4c/relu_5x5 does not need backward computation.
# I0707 15:13:23.585053   340 net.cpp:222] inception_4c/5x5 does not need backward computation.
# I0707 15:13:23.585064   340 net.cpp:222] inception_4c/relu_5x5_reduce does not need backward computation.
# I0707 15:13:23.585068   340 net.cpp:222] inception_4c/5x5_reduce does not need backward computation.
# I0707 15:13:23.585078   340 net.cpp:222] inception_4c/relu_3x3 does not need backward computation.
# I0707 15:13:23.585083   340 net.cpp:222] inception_4c/3x3 does not need backward computation.
# I0707 15:13:23.585090   340 net.cpp:222] inception_4c/relu_3x3_reduce does not need backward computation.
# I0707 15:13:23.585094   340 net.cpp:222] inception_4c/3x3_reduce does not need backward computation.
# I0707 15:13:23.585104   340 net.cpp:222] inception_4c/relu_1x1 does not need backward computation.
# I0707 15:13:23.585108   340 net.cpp:222] inception_4c/1x1 does not need backward computation.
# I0707 15:13:23.585117   340 net.cpp:222] inception_4b/output_inception_4b/output_0_split does not need backward computation.
# I0707 15:13:23.585125   340 net.cpp:222] inception_4b/output does not need backward computation.
# I0707 15:13:23.585139   340 net.cpp:222] inception_4b/relu_pool_proj does not need backward computation.
# I0707 15:13:23.585147   340 net.cpp:222] inception_4b/pool_proj does not need backward computation.
# I0707 15:13:23.585157   340 net.cpp:222] inception_4b/pool does not need backward computation.
# I0707 15:13:23.585166   340 net.cpp:222] inception_4b/relu_5x5 does not need backward computation.
# I0707 15:13:23.585175   340 net.cpp:222] inception_4b/5x5 does not need backward computation.
# I0707 15:13:23.585189   340 net.cpp:222] inception_4b/relu_5x5_reduce does not need backward computation.
# I0707 15:13:23.585197   340 net.cpp:222] inception_4b/5x5_reduce does not need backward computation.
# I0707 15:13:23.585206   340 net.cpp:222] inception_4b/relu_3x3 does not need backward computation.
# I0707 15:13:23.585217   340 net.cpp:222] inception_4b/3x3 does not need backward computation.
# I0707 15:13:23.585224   340 net.cpp:222] inception_4b/relu_3x3_reduce does not need backward computation.
# I0707 15:13:23.585235   340 net.cpp:222] inception_4b/3x3_reduce does not need backward computation.
# I0707 15:13:23.585242   340 net.cpp:222] inception_4b/relu_1x1 does not need backward computation.
# I0707 15:13:23.585254   340 net.cpp:222] inception_4b/1x1 does not need backward computation.
# I0707 15:13:23.585263   340 net.cpp:222] inception_4a/output_inception_4a/output_0_split does not need backward computation.
# I0707 15:13:23.585273   340 net.cpp:222] inception_4a/output does not need backward computation.
# I0707 15:13:23.585283   340 net.cpp:222] inception_4a/relu_pool_proj does not need backward computation.
# I0707 15:13:23.585292   340 net.cpp:222] inception_4a/pool_proj does not need backward computation.
# I0707 15:13:23.585304   340 net.cpp:222] inception_4a/pool does not need backward computation.
# I0707 15:13:23.585311   340 net.cpp:222] inception_4a/relu_5x5 does not need backward computation.
# I0707 15:13:23.585322   340 net.cpp:222] inception_4a/5x5 does not need backward computation.
# I0707 15:13:23.585330   340 net.cpp:222] inception_4a/relu_5x5_reduce does not need backward computation.
# I0707 15:13:23.585341   340 net.cpp:222] inception_4a/5x5_reduce does not need backward computation.
# I0707 15:13:23.585353   340 net.cpp:222] inception_4a/relu_3x3 does not need backward computation.
# I0707 15:13:23.585361   340 net.cpp:222] inception_4a/3x3 does not need backward computation.
# I0707 15:13:23.585373   340 net.cpp:222] inception_4a/relu_3x3_reduce does not need backward computation.
# I0707 15:13:23.585379   340 net.cpp:222] inception_4a/3x3_reduce does not need backward computation.
# I0707 15:13:23.585391   340 net.cpp:222] inception_4a/relu_1x1 does not need backward computation.
# I0707 15:13:23.585405   340 net.cpp:222] inception_4a/1x1 does not need backward computation.
# I0707 15:13:23.585414   340 net.cpp:222] pool3/3x3_s2_pool3/3x3_s2_0_split does not need backward computation.
# I0707 15:13:23.585422   340 net.cpp:222] pool3/3x3_s2 does not need backward computation.
# I0707 15:13:23.585430   340 net.cpp:222] inception_3b/output does not need backward computation.
# I0707 15:13:23.585444   340 net.cpp:222] inception_3b/relu_pool_proj does not need backward computation.
# I0707 15:13:23.585453   340 net.cpp:222] inception_3b/pool_proj does not need backward computation.
# I0707 15:13:23.585460   340 net.cpp:222] inception_3b/pool does not need backward computation.
# I0707 15:13:23.585469   340 net.cpp:222] inception_3b/relu_5x5 does not need backward computation.
# I0707 15:13:23.585475   340 net.cpp:222] inception_3b/5x5 does not need backward computation.
# I0707 15:13:23.585484   340 net.cpp:222] inception_3b/relu_5x5_reduce does not need backward computation.
# I0707 15:13:23.585491   340 net.cpp:222] inception_3b/5x5_reduce does not need backward computation.
# I0707 15:13:23.585502   340 net.cpp:222] inception_3b/relu_3x3 does not need backward computation.
# I0707 15:13:23.585510   340 net.cpp:222] inception_3b/3x3 does not need backward computation.
# I0707 15:13:23.585521   340 net.cpp:222] inception_3b/relu_3x3_reduce does not need backward computation.
# I0707 15:13:23.585536   340 net.cpp:222] inception_3b/3x3_reduce does not need backward computation.
# I0707 15:13:23.585543   340 net.cpp:222] inception_3b/relu_1x1 does not need backward computation.
# I0707 15:13:23.585551   340 net.cpp:222] inception_3b/1x1 does not need backward computation.
# I0707 15:13:23.585562   340 net.cpp:222] inception_3a/output_inception_3a/output_0_split does not need backward computation.
# I0707 15:13:23.585574   340 net.cpp:222] inception_3a/output does not need backward computation.
# I0707 15:13:23.585583   340 net.cpp:222] inception_3a/relu_pool_proj does not need backward computation.
# I0707 15:13:23.585594   340 net.cpp:222] inception_3a/pool_proj does not need backward computation.
# I0707 15:13:23.585603   340 net.cpp:222] inception_3a/pool does not need backward computation.
# I0707 15:13:23.585614   340 net.cpp:222] inception_3a/relu_5x5 does not need backward computation.
# I0707 15:13:23.585621   340 net.cpp:222] inception_3a/5x5 does not need backward computation.
# I0707 15:13:23.585634   340 net.cpp:222] inception_3a/relu_5x5_reduce does not need backward computation.
# I0707 15:13:23.585646   340 net.cpp:222] inception_3a/5x5_reduce does not need backward computation.
# I0707 15:13:23.585659   340 net.cpp:222] inception_3a/relu_3x3 does not need backward computation.
# I0707 15:13:23.585667   340 net.cpp:222] inception_3a/3x3 does not need backward computation.
# I0707 15:13:23.585676   340 net.cpp:222] inception_3a/relu_3x3_reduce does not need backward computation.
# I0707 15:13:23.585685   340 net.cpp:222] inception_3a/3x3_reduce does not need backward computation.
# I0707 15:13:23.585693   340 net.cpp:222] inception_3a/relu_1x1 does not need backward computation.
# I0707 15:13:23.585702   340 net.cpp:222] inception_3a/1x1 does not need backward computation.
# I0707 15:13:23.585712   340 net.cpp:222] pool2/3x3_s2_pool2/3x3_s2_0_split does not need backward computation.
# I0707 15:13:23.585721   340 net.cpp:222] pool2/3x3_s2 does not need backward computation.
# I0707 15:13:23.585731   340 net.cpp:222] conv2/norm2 does not need backward computation.
# I0707 15:13:23.585739   340 net.cpp:222] conv2/relu_3x3 does not need backward computation.
# I0707 15:13:23.585748   340 net.cpp:222] conv2/3x3 does not need backward computation.
# I0707 15:13:23.585757   340 net.cpp:222] conv2/relu_3x3_reduce does not need backward computation.
# I0707 15:13:23.585768   340 net.cpp:222] conv2/3x3_reduce does not need backward computation.
# I0707 15:13:23.585777   340 net.cpp:222] pool1/norm1 does not need backward computation.
# I0707 15:13:23.585788   340 net.cpp:222] pool1/3x3_s2 does not need backward computation.
# I0707 15:13:23.585796   340 net.cpp:222] conv1/relu_7x7 does not need backward computation.
# I0707 15:13:23.585804   340 net.cpp:222] conv1/7x7_s2 does not need backward computation.
# I0707 15:13:23.585813   340 net.cpp:222] input does not need backward computation.
# I0707 15:13:23.585822   340 net.cpp:264] This network produces output softmax
# I0707 15:13:23.585942   340 net.cpp:284] Network initialization done.
# I0707 15:13:23.613879   340 net.cpp:791] Ignoring source layer train-data
# I0707 15:13:23.613912   340 net.cpp:791] Ignoring source layer label_train-data_1_split
# I0707 15:13:23.614866   340 net.cpp:791] Ignoring source layer loss1/ave_pool
# I0707 15:13:23.614881   340 net.cpp:791] Ignoring source layer loss1/conv
# I0707 15:13:23.614886   340 net.cpp:791] Ignoring source layer loss1/relu_conv
# I0707 15:13:23.614897   340 net.cpp:791] Ignoring source layer loss1/fc
# I0707 15:13:23.614905   340 net.cpp:791] Ignoring source layer loss1/relu_fc
# I0707 15:13:23.614912   340 net.cpp:791] Ignoring source layer loss1/drop_fc
# I0707 15:13:23.614922   340 net.cpp:791] Ignoring source layer loss1/classifier
# I0707 15:13:23.614928   340 net.cpp:791] Ignoring source layer loss1/loss
# I0707 15:13:23.616283   340 net.cpp:791] Ignoring source layer loss2/ave_pool
# I0707 15:13:23.616298   340 net.cpp:791] Ignoring source layer loss2/conv
# I0707 15:13:23.616305   340 net.cpp:791] Ignoring source layer loss2/relu_conv
# I0707 15:13:23.616315   340 net.cpp:791] Ignoring source layer loss2/fc
# I0707 15:13:23.616328   340 net.cpp:791] Ignoring source layer loss2/relu_fc
# I0707 15:13:23.616340   340 net.cpp:791] Ignoring source layer loss2/drop_fc
# I0707 15:13:23.616353   340 net.cpp:791] Ignoring source layer loss2/classifier
# I0707 15:13:23.616361   340 net.cpp:791] Ignoring source layer loss2/loss
# I0707 15:13:23.618968   340 net.cpp:791] Ignoring source layer loss3/loss
# whale

# %%
# !python submission.py '/dli/data/whale/data/train/not_face/w_1.jpg' #This should return "not whale" at the very bottom of the output.
# Out:
# WARNING: Logging before InitGoogleLogging() is written to STDERR
# I0707 15:13:36.005960   353 upgrade_proto.cpp:66] Attempting to upgrade input file specified using deprecated input fields: /dli/data/digits/20180707-145226-135e/deploy.prototxt
# I0707 15:13:36.006024   353 upgrade_proto.cpp:69] Successfully upgraded file specified using deprecated input fields.
# W0707 15:13:36.006038   353 upgrade_proto.cpp:71] Note that future Caffe releases will only support input layers and not input fields.
# I0707 15:13:36.006925   353 net.cpp:52] Initializing net from parameters:
# state {
#   phase: TEST
# }
# layer {
#   name: "input"
#   type: "Input"
#   top: "data"
#   input_param {
#     shape {
#       dim: 1
#       dim: 3
#       dim: 224
#       dim: 224
#     }
#   }
# }
# layer {
#   name: "conv1/7x7_s2"
#   type: "Convolution"
#   bottom: "data"
#   top: "conv1/7x7_s2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 64
#     pad: 3
#     kernel_size: 7
#     stride: 2
#     weight_filler {
#       type: "xavier"
#       std: 0.1
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "conv1/relu_7x7"
#   type: "ReLU"
#   bottom: "conv1/7x7_s2"
#   top: "conv1/7x7_s2"
# }
# layer {
#   name: "pool1/3x3_s2"
#   type: "Pooling"
#   bottom: "conv1/7x7_s2"
#   top: "pool1/3x3_s2"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "pool1/norm1"
#   type: "LRN"
#   bottom: "pool1/3x3_s2"
#   top: "pool1/norm1"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "conv2/3x3_reduce"
#   type: "Convolution"
#   bottom: "pool1/norm1"
#   top: "conv2/3x3_reduce"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 64
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.1
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "conv2/relu_3x3_reduce"
#   type: "ReLU"
#   bottom: "conv2/3x3_reduce"
#   top: "conv2/3x3_reduce"
# }
# layer {
#   name: "conv2/3x3"
#   type: "Convolution"
#   bottom: "conv2/3x3_reduce"
#   top: "conv2/3x3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 192
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "conv2/relu_3x3"
#   type: "ReLU"
#   bottom: "conv2/3x3"
#   top: "conv2/3x3"
# }
# layer {
#   name: "conv2/norm2"
#   type: "LRN"
#   bottom: "conv2/3x3"
#   top: "conv2/norm2"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool2/3x3_s2"
#   type: "Pooling"
#   bottom: "conv2/norm2"
#   top: "pool2/3x3_s2"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "inception_3a/1x1"
#   type: "Convolution"
#   bottom: "pool2/3x3_s2"
#   top: "inception_3a/1x1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 64
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_3a/relu_1x1"
#   type: "ReLU"
#   bottom: "inception_3a/1x1"
#   top: "inception_3a/1x1"
# }
# layer {
#   name: "inception_3a/3x3_reduce"
#   type: "Convolution"
#   bottom: "pool2/3x3_s2"
#   top: "inception_3a/3x3_reduce"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 96
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.09
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_3a/relu_3x3_reduce"
#   type: "ReLU"
#   bottom: "inception_3a/3x3_reduce"
#   top: "inception_3a/3x3_reduce"
# }
# layer {
#   name: "inception_3a/3x3"
#   type: "Convolution"
#   bottom: "inception_3a/3x3_reduce"
#   top: "inception_3a/3x3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 128
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_3a/relu_3x3"
#   type: "ReLU"
#   bottom: "inception_3a/3x3"
#   top: "inception_3a/3x3"
# }
# layer {
#   name: "inception_3a/5x5_reduce"
#   type: "Convolution"
#   bottom: "pool2/3x3_s2"
#   top: "inception_3a/5x5_reduce"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 16
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.2
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_3a/relu_5x5_reduce"
#   type: "ReLU"
#   bottom: "inception_3a/5x5_reduce"
#   top: "inception_3a/5x5_reduce"
# }
# layer {
#   name: "inception_3a/5x5"
#   type: "Convolution"
#   bottom: "inception_3a/5x5_reduce"
#   top: "inception_3a/5x5"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 32
#     pad: 2
#     kernel_size: 5
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_3a/relu_5x5"
#   type: "ReLU"
#   bottom: "inception_3a/5x5"
#   top: "inception_3a/5x5"
# }
# layer {
#   name: "inception_3a/pool"
#   type: "Pooling"
#   bottom: "pool2/3x3_s2"
#   top: "inception_3a/pool"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 1
#     pad: 1
#   }
# }
# layer {
#   name: "inception_3a/pool_proj"
#   type: "Convolution"
#   bottom: "inception_3a/pool"
#   top: "inception_3a/pool_proj"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 32
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.1
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_3a/relu_pool_proj"
#   type: "ReLU"
#   bottom: "inception_3a/pool_proj"
#   top: "inception_3a/pool_proj"
# }
# layer {
#   name: "inception_3a/output"
#   type: "Concat"
#   bottom: "inception_3a/1x1"
#   bottom: "inception_3a/3x3"
#   bottom: "inception_3a/5x5"
#   bottom: "inception_3a/pool_proj"
#   top: "inception_3a/output"
# }
# layer {
#   name: "inception_3b/1x1"
#   type: "Convolution"
#   bottom: "inception_3a/output"
#   top: "inception_3b/1x1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 128
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_3b/relu_1x1"
#   type: "ReLU"
#   bottom: "inception_3b/1x1"
#   top: "inception_3b/1x1"
# }
# layer {
#   name: "inception_3b/3x3_reduce"
#   type: "Convolution"
#   bottom: "inception_3a/output"
#   top: "inception_3b/3x3_reduce"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 128
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.09
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_3b/relu_3x3_reduce"
#   type: "ReLU"
#   bottom: "inception_3b/3x3_reduce"
#   top: "inception_3b/3x3_reduce"
# }
# layer {
#   name: "inception_3b/3x3"
#   type: "Convolution"
#   bottom: "inception_3b/3x3_reduce"
#   top: "inception_3b/3x3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 192
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_3b/relu_3x3"
#   type: "ReLU"
#   bottom: "inception_3b/3x3"
#   top: "inception_3b/3x3"
# }
# layer {
#   name: "inception_3b/5x5_reduce"
#   type: "Convolution"
#   bottom: "inception_3a/output"
#   top: "inception_3b/5x5_reduce"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 32
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.2
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_3b/relu_5x5_reduce"
#   type: "ReLU"
#   bottom: "inception_3b/5x5_reduce"
#   top: "inception_3b/5x5_reduce"
# }
# layer {
#   name: "inception_3b/5x5"
#   type: "Convolution"
#   bottom: "inception_3b/5x5_reduce"
#   top: "inception_3b/5x5"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 96
#     pad: 2
#     kernel_size: 5
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_3b/relu_5x5"
#   type: "ReLU"
#   bottom: "inception_3b/5x5"
#   top: "inception_3b/5x5"
# }
# layer {
#   name: "inception_3b/pool"
#   type: "Pooling"
#   bottom: "inception_3a/output"
#   top: "inception_3b/pool"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 1
#     pad: 1
#   }
# }
# layer {
#   name: "inception_3b/pool_proj"
#   type: "Convolution"
#   bottom: "inception_3b/pool"
#   top: "inception_3b/pool_proj"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 64
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.1
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_3b/relu_pool_proj"
#   type: "ReLU"
#   bottom: "inception_3b/pool_proj"
#   top: "inception_3b/pool_proj"
# }
# layer {
#   name: "inception_3b/output"
#   type: "Concat"
#   bottom: "inception_3b/1x1"
#   bottom: "inception_3b/3x3"
#   bottom: "inception_3b/5x5"
#   bottom: "inception_3b/pool_proj"
#   top: "inception_3b/output"
# }
# layer {
#   name: "pool3/3x3_s2"
#   type: "Pooling"
#   bottom: "inception_3b/output"
#   top: "pool3/3x3_s2"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "inception_4a/1x1"
#   type: "Convolution"
#   bottom: "pool3/3x3_s2"
#   top: "inception_4a/1x1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 192
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4a/relu_1x1"
#   type: "ReLU"
#   bottom: "inception_4a/1x1"
#   top: "inception_4a/1x1"
# }
# layer {
#   name: "inception_4a/3x3_reduce"
#   type: "Convolution"
#   bottom: "pool3/3x3_s2"
#   top: "inception_4a/3x3_reduce"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 96
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.09
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4a/relu_3x3_reduce"
#   type: "ReLU"
#   bottom: "inception_4a/3x3_reduce"
#   top: "inception_4a/3x3_reduce"
# }
# layer {
#   name: "inception_4a/3x3"
#   type: "Convolution"
#   bottom: "inception_4a/3x3_reduce"
#   top: "inception_4a/3x3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 208
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4a/relu_3x3"
#   type: "ReLU"
#   bottom: "inception_4a/3x3"
#   top: "inception_4a/3x3"
# }
# layer {
#   name: "inception_4a/5x5_reduce"
#   type: "Convolution"
#   bottom: "pool3/3x3_s2"
#   top: "inception_4a/5x5_reduce"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 16
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.2
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4a/relu_5x5_reduce"
#   type: "ReLU"
#   bottom: "inception_4a/5x5_reduce"
#   top: "inception_4a/5x5_reduce"
# }
# layer {
#   name: "inception_4a/5x5"
#   type: "Convolution"
#   bottom: "inception_4a/5x5_reduce"
#   top: "inception_4a/5x5"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 48
#     pad: 2
#     kernel_size: 5
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4a/relu_5x5"
#   type: "ReLU"
#   bottom: "inception_4a/5x5"
#   top: "inception_4a/5x5"
# }
# layer {
#   name: "inception_4a/pool"
#   type: "Pooling"
#   bottom: "pool3/3x3_s2"
#   top: "inception_4a/pool"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 1
#     pad: 1
#   }
# }
# layer {
#   name: "inception_4a/pool_proj"
#   type: "Convolution"
#   bottom: "inception_4a/pool"
#   top: "inception_4a/pool_proj"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 64
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.1
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4a/relu_pool_proj"
#   type: "ReLU"
#   bottom: "inception_4a/pool_proj"
#   top: "inception_4a/pool_proj"
# }
# layer {
#   name: "inception_4a/output"
#   type: "Concat"
#   bottom: "inception_4a/1x1"
#   bottom: "inception_4a/3x3"
#   bottom: "inception_4a/5x5"
#   bottom: "inception_4a/pool_proj"
#   top: "inception_4a/output"
# }
# layer {
#   name: "inception_4b/1x1"
#   type: "Convolution"
#   bottom: "inception_4a/output"
#   top: "inception_4b/1x1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 160
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4b/relu_1x1"
#   type: "ReLU"
#   bottom: "inception_4b/1x1"
#   top: "inception_4b/1x1"
# }
# layer {
#   name: "inception_4b/3x3_reduce"
#   type: "Convolution"
#   bottom: "inception_4a/output"
#   top: "inception_4b/3x3_reduce"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 112
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.09
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4b/relu_3x3_reduce"
#   type: "ReLU"
#   bottom: "inception_4b/3x3_reduce"
#   top: "inception_4b/3x3_reduce"
# }
# layer {
#   name: "inception_4b/3x3"
#   type: "Convolution"
#   bottom: "inception_4b/3x3_reduce"
#   top: "inception_4b/3x3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 224
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4b/relu_3x3"
#   type: "ReLU"
#   bottom: "inception_4b/3x3"
#   top: "inception_4b/3x3"
# }
# layer {
#   name: "inception_4b/5x5_reduce"
#   type: "Convolution"
#   bottom: "inception_4a/output"
#   top: "inception_4b/5x5_reduce"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 24
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.2
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4b/relu_5x5_reduce"
#   type: "ReLU"
#   bottom: "inception_4b/5x5_reduce"
#   top: "inception_4b/5x5_reduce"
# }
# layer {
#   name: "inception_4b/5x5"
#   type: "Convolution"
#   bottom: "inception_4b/5x5_reduce"
#   top: "inception_4b/5x5"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 64
#     pad: 2
#     kernel_size: 5
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4b/relu_5x5"
#   type: "ReLU"
#   bottom: "inception_4b/5x5"
#   top: "inception_4b/5x5"
# }
# layer {
#   name: "inception_4b/pool"
#   type: "Pooling"
#   bottom: "inception_4a/output"
#   top: "inception_4b/pool"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 1
#     pad: 1
#   }
# }
# layer {
#   name: "inception_4b/pool_proj"
#   type: "Convolution"
#   bottom: "inception_4b/pool"
#   top: "inception_4b/pool_proj"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 64
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.1
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4b/relu_pool_proj"
#   type: "ReLU"
#   bottom: "inception_4b/pool_proj"
#   top: "inception_4b/pool_proj"
# }
# layer {
#   name: "inception_4b/output"
#   type: "Concat"
#   bottom: "inception_4b/1x1"
#   bottom: "inception_4b/3x3"
#   bottom: "inception_4b/5x5"
#   bottom: "inception_4b/pool_proj"
#   top: "inception_4b/output"
# }
# layer {
#   name: "inception_4c/1x1"
#   type: "Convolution"
#   bottom: "inception_4b/output"
#   top: "inception_4c/1x1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 128
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4c/relu_1x1"
#   type: "ReLU"
#   bottom: "inception_4c/1x1"
#   top: "inception_4c/1x1"
# }
# layer {
#   name: "inception_4c/3x3_reduce"
#   type: "Convolution"
#   bottom: "inception_4b/output"
#   top: "inception_4c/3x3_reduce"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 128
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.09
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4c/relu_3x3_reduce"
#   type: "ReLU"
#   bottom: "inception_4c/3x3_reduce"
#   top: "inception_4c/3x3_reduce"
# }
# layer {
#   name: "inception_4c/3x3"
#   type: "Convolution"
#   bottom: "inception_4c/3x3_reduce"
#   top: "inception_4c/3x3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4c/relu_3x3"
#   type: "ReLU"
#   bottom: "inception_4c/3x3"
#   top: "inception_4c/3x3"
# }
# layer {
#   name: "inception_4c/5x5_reduce"
#   type: "Convolution"
#   bottom: "inception_4b/output"
#   top: "inception_4c/5x5_reduce"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 24
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.2
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4c/relu_5x5_reduce"
#   type: "ReLU"
#   bottom: "inception_4c/5x5_reduce"
#   top: "inception_4c/5x5_reduce"
# }
# layer {
#   name: "inception_4c/5x5"
#   type: "Convolution"
#   bottom: "inception_4c/5x5_reduce"
#   top: "inception_4c/5x5"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 64
#     pad: 2
#     kernel_size: 5
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4c/relu_5x5"
#   type: "ReLU"
#   bottom: "inception_4c/5x5"
#   top: "inception_4c/5x5"
# }
# layer {
#   name: "inception_4c/pool"
#   type: "Pooling"
#   bottom: "inception_4b/output"
#   top: "inception_4c/pool"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 1
#     pad: 1
#   }
# }
# layer {
#   name: "inception_4c/pool_proj"
#   type: "Convolution"
#   bottom: "inception_4c/pool"
#   top: "inception_4c/pool_proj"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 64
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.1
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4c/relu_pool_proj"
#   type: "ReLU"
#   bottom: "inception_4c/pool_proj"
#   top: "inception_4c/pool_proj"
# }
# layer {
#   name: "inception_4c/output"
#   type: "Concat"
#   bottom: "inception_4c/1x1"
#   bottom: "inception_4c/3x3"
#   bottom: "inception_4c/5x5"
#   bottom: "inception_4c/pool_proj"
#   top: "inception_4c/output"
# }
# layer {
#   name: "inception_4d/1x1"
#   type: "Convolution"
#   bottom: "inception_4c/output"
#   top: "inception_4d/1x1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 112
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4d/relu_1x1"
#   type: "ReLU"
#   bottom: "inception_4d/1x1"
#   top: "inception_4d/1x1"
# }
# layer {
#   name: "inception_4d/3x3_reduce"
#   type: "Convolution"
#   bottom: "inception_4c/output"
#   top: "inception_4d/3x3_reduce"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 144
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.09
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4d/relu_3x3_reduce"
#   type: "ReLU"
#   bottom: "inception_4d/3x3_reduce"
#   top: "inception_4d/3x3_reduce"
# }
# layer {
#   name: "inception_4d/3x3"
#   type: "Convolution"
#   bottom: "inception_4d/3x3_reduce"
#   top: "inception_4d/3x3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 288
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4d/relu_3x3"
#   type: "ReLU"
#   bottom: "inception_4d/3x3"
#   top: "inception_4d/3x3"
# }
# layer {
#   name: "inception_4d/5x5_reduce"
#   type: "Convolution"
#   bottom: "inception_4c/output"
#   top: "inception_4d/5x5_reduce"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 32
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.2
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4d/relu_5x5_reduce"
#   type: "ReLU"
#   bottom: "inception_4d/5x5_reduce"
#   top: "inception_4d/5x5_reduce"
# }
# layer {
#   name: "inception_4d/5x5"
#   type: "Convolution"
#   bottom: "inception_4d/5x5_reduce"
#   top: "inception_4d/5x5"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 64
#     pad: 2
#     kernel_size: 5
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4d/relu_5x5"
#   type: "ReLU"
#   bottom: "inception_4d/5x5"
#   top: "inception_4d/5x5"
# }
# layer {
#   name: "inception_4d/pool"
#   type: "Pooling"
#   bottom: "inception_4c/output"
#   top: "inception_4d/pool"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 1
#     pad: 1
#   }
# }
# layer {
#   name: "inception_4d/pool_proj"
#   type: "Convolution"
#   bottom: "inception_4d/pool"
#   top: "inception_4d/pool_proj"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 64
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.1
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4d/relu_pool_proj"
#   type: "ReLU"
#   bottom: "inception_4d/pool_proj"
#   top: "inception_4d/pool_proj"
# }
# layer {
#   name: "inception_4d/output"
#   type: "Concat"
#   bottom: "inception_4d/1x1"
#   bottom: "inception_4d/3x3"
#   bottom: "inception_4d/5x5"
#   bottom: "inception_4d/pool_proj"
#   top: "inception_4d/output"
# }
# layer {
#   name: "inception_4e/1x1"
#   type: "Convolution"
#   bottom: "inception_4d/output"
#   top: "inception_4e/1x1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4e/relu_1x1"
#   type: "ReLU"
#   bottom: "inception_4e/1x1"
#   top: "inception_4e/1x1"
# }
# layer {
#   name: "inception_4e/3x3_reduce"
#   type: "Convolution"
#   bottom: "inception_4d/output"
#   top: "inception_4e/3x3_reduce"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 160
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.09
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4e/relu_3x3_reduce"
#   type: "ReLU"
#   bottom: "inception_4e/3x3_reduce"
#   top: "inception_4e/3x3_reduce"
# }
# layer {
#   name: "inception_4e/3x3"
#   type: "Convolution"
#   bottom: "inception_4e/3x3_reduce"
#   top: "inception_4e/3x3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 320
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4e/relu_3x3"
#   type: "ReLU"
#   bottom: "inception_4e/3x3"
#   top: "inception_4e/3x3"
# }
# layer {
#   name: "inception_4e/5x5_reduce"
#   type: "Convolution"
#   bottom: "inception_4d/output"
#   top: "inception_4e/5x5_reduce"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 32
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.2
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4e/relu_5x5_reduce"
#   type: "ReLU"
#   bottom: "inception_4e/5x5_reduce"
#   top: "inception_4e/5x5_reduce"
# }
# layer {
#   name: "inception_4e/5x5"
#   type: "Convolution"
#   bottom: "inception_4e/5x5_reduce"
#   top: "inception_4e/5x5"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 128
#     pad: 2
#     kernel_size: 5
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4e/relu_5x5"
#   type: "ReLU"
#   bottom: "inception_4e/5x5"
#   top: "inception_4e/5x5"
# }
# layer {
#   name: "inception_4e/pool"
#   type: "Pooling"
#   bottom: "inception_4d/output"
#   top: "inception_4e/pool"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 1
#     pad: 1
#   }
# }
# layer {
#   name: "inception_4e/pool_proj"
#   type: "Convolution"
#   bottom: "inception_4e/pool"
#   top: "inception_4e/pool_proj"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 128
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.1
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_4e/relu_pool_proj"
#   type: "ReLU"
#   bottom: "inception_4e/pool_proj"
#   top: "inception_4e/pool_proj"
# }
# layer {
#   name: "inception_4e/output"
#   type: "Concat"
#   bottom: "inception_4e/1x1"
#   bottom: "inception_4e/3x3"
#   bottom: "inception_4e/5x5"
#   bottom: "inception_4e/pool_proj"
#   top: "inception_4e/output"
# }
# layer {
#   name: "pool4/3x3_s2"
#   type: "Pooling"
#   bottom: "inception_4e/output"
#   top: "pool4/3x3_s2"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "inception_5a/1x1"
#   type: "Convolution"
#   bottom: "pool4/3x3_s2"
#   top: "inception_5a/1x1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_5a/relu_1x1"
#   type: "ReLU"
#   bottom: "inception_5a/1x1"
#   top: "inception_5a/1x1"
# }
# layer {
#   name: "inception_5a/3x3_reduce"
#   type: "Convolution"
#   bottom: "pool4/3x3_s2"
#   top: "inception_5a/3x3_reduce"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 160
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.09
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_5a/relu_3x3_reduce"
#   type: "ReLU"
#   bottom: "inception_5a/3x3_reduce"
#   top: "inception_5a/3x3_reduce"
# }
# layer {
#   name: "inception_5a/3x3"
#   type: "Convolution"
#   bottom: "inception_5a/3x3_reduce"
#   top: "inception_5a/3x3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 320
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "xavier"
#       std: 0.03
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   name: "inception_5a/relu_3x3"
#   type: "ReLU"
#   bottom: "inception_5a/3x3"
#   top: "inception_5a/3x3"
# }
# layer {
#   name: "inception_5a/5x5_reduce"
#   type: "Convolution"
#   bottom: "pool4/3x3_s2"
#   top: "inception_5a/5x5_reduce"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 32
#     kernel_size: 1
#     weight_filler {
#       type: "xavier"
#       std: 0.2
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.2
#     }
#   }
# }
# layer {
#   na
# I0707 15:13:36.012130   353 layer_factory.hpp:77] Creating layer input
# I0707 15:13:36.012164   353 net.cpp:94] Creating Layer input
# I0707 15:13:36.012176   353 net.cpp:409] input -> data
# I0707 15:13:36.012869   353 net.cpp:144] Setting up input
# I0707 15:13:36.012892   353 net.cpp:151] Top shape: 1 3 224 224 (150528)
# I0707 15:13:36.012903   353 net.cpp:159] Memory required for data: 602112
# I0707 15:13:36.012909   353 layer_factory.hpp:77] Creating layer conv1/7x7_s2
# I0707 15:13:36.012926   353 net.cpp:94] Creating Layer conv1/7x7_s2
# I0707 15:13:36.012936   353 net.cpp:435] conv1/7x7_s2 <- data
# I0707 15:13:36.012948   353 net.cpp:409] conv1/7x7_s2 -> conv1/7x7_s2
# I0707 15:13:36.014164   353 net.cpp:144] Setting up conv1/7x7_s2
# I0707 15:13:36.014186   353 net.cpp:151] Top shape: 1 64 112 112 (802816)
# I0707 15:13:36.014194   353 net.cpp:159] Memory required for data: 3813376
# I0707 15:13:36.014211   353 layer_factory.hpp:77] Creating layer conv1/relu_7x7
# I0707 15:13:36.014225   353 net.cpp:94] Creating Layer conv1/relu_7x7
# I0707 15:13:36.014235   353 net.cpp:435] conv1/relu_7x7 <- conv1/7x7_s2
# I0707 15:13:36.014247   353 net.cpp:396] conv1/relu_7x7 -> conv1/7x7_s2 (in-place)
# I0707 15:13:36.014262   353 net.cpp:144] Setting up conv1/relu_7x7
# I0707 15:13:36.014272   353 net.cpp:151] Top shape: 1 64 112 112 (802816)
# I0707 15:13:36.014281   353 net.cpp:159] Memory required for data: 7024640
# I0707 15:13:36.014294   353 layer_factory.hpp:77] Creating layer pool1/3x3_s2
# I0707 15:13:36.014305   353 net.cpp:94] Creating Layer pool1/3x3_s2
# I0707 15:13:36.014314   353 net.cpp:435] pool1/3x3_s2 <- conv1/7x7_s2
# I0707 15:13:36.014322   353 net.cpp:409] pool1/3x3_s2 -> pool1/3x3_s2
# I0707 15:13:36.014369   353 net.cpp:144] Setting up pool1/3x3_s2
# I0707 15:13:36.014384   353 net.cpp:151] Top shape: 1 64 56 56 (200704)
# I0707 15:13:36.014394   353 net.cpp:159] Memory required for data: 7827456
# I0707 15:13:36.014402   353 layer_factory.hpp:77] Creating layer pool1/norm1
# I0707 15:13:36.014415   353 net.cpp:94] Creating Layer pool1/norm1
# I0707 15:13:36.014422   353 net.cpp:435] pool1/norm1 <- pool1/3x3_s2
# I0707 15:13:36.014430   353 net.cpp:409] pool1/norm1 -> pool1/norm1
# I0707 15:13:36.014467   353 net.cpp:144] Setting up pool1/norm1
# I0707 15:13:36.014479   353 net.cpp:151] Top shape: 1 64 56 56 (200704)
# I0707 15:13:36.014483   353 net.cpp:159] Memory required for data: 8630272
# I0707 15:13:36.014487   353 layer_factory.hpp:77] Creating layer conv2/3x3_reduce
# I0707 15:13:36.014502   353 net.cpp:94] Creating Layer conv2/3x3_reduce
# I0707 15:13:36.014510   353 net.cpp:435] conv2/3x3_reduce <- pool1/norm1
# I0707 15:13:36.014518   353 net.cpp:409] conv2/3x3_reduce -> conv2/3x3_reduce
# I0707 15:13:36.015327   353 net.cpp:144] Setting up conv2/3x3_reduce
# I0707 15:13:36.015349   353 net.cpp:151] Top shape: 1 64 56 56 (200704)
# I0707 15:13:36.015359   353 net.cpp:159] Memory required for data: 9433088
# I0707 15:13:36.015378   353 layer_factory.hpp:77] Creating layer conv2/relu_3x3_reduce
# I0707 15:13:36.015388   353 net.cpp:94] Creating Layer conv2/relu_3x3_reduce
# I0707 15:13:36.015398   353 net.cpp:435] conv2/relu_3x3_reduce <- conv2/3x3_reduce
# I0707 15:13:36.015404   353 net.cpp:396] conv2/relu_3x3_reduce -> conv2/3x3_reduce (in-place)
# I0707 15:13:36.015417   353 net.cpp:144] Setting up conv2/relu_3x3_reduce
# I0707 15:13:36.015429   353 net.cpp:151] Top shape: 1 64 56 56 (200704)
# I0707 15:13:36.015432   353 net.cpp:159] Memory required for data: 10235904
# I0707 15:13:36.015440   353 layer_factory.hpp:77] Creating layer conv2/3x3
# I0707 15:13:36.015455   353 net.cpp:94] Creating Layer conv2/3x3
# I0707 15:13:36.015465   353 net.cpp:435] conv2/3x3 <- conv2/3x3_reduce
# I0707 15:13:36.015473   353 net.cpp:409] conv2/3x3 -> conv2/3x3
# I0707 15:13:36.016875   353 net.cpp:144] Setting up conv2/3x3
# I0707 15:13:36.016896   353 net.cpp:151] Top shape: 1 192 56 56 (602112)
# I0707 15:13:36.016903   353 net.cpp:159] Memory required for data: 12644352
# I0707 15:13:36.016914   353 layer_factory.hpp:77] Creating layer conv2/relu_3x3
# I0707 15:13:36.016932   353 net.cpp:94] Creating Layer conv2/relu_3x3
# I0707 15:13:36.016937   353 net.cpp:435] conv2/relu_3x3 <- conv2/3x3
# I0707 15:13:36.016945   353 net.cpp:396] conv2/relu_3x3 -> conv2/3x3 (in-place)
# I0707 15:13:36.016959   353 net.cpp:144] Setting up conv2/relu_3x3
# I0707 15:13:36.016969   353 net.cpp:151] Top shape: 1 192 56 56 (602112)
# I0707 15:13:36.016973   353 net.cpp:159] Memory required for data: 15052800
# I0707 15:13:36.016983   353 layer_factory.hpp:77] Creating layer conv2/norm2
# I0707 15:13:36.016988   353 net.cpp:94] Creating Layer conv2/norm2
# I0707 15:13:36.016997   353 net.cpp:435] conv2/norm2 <- conv2/3x3
# I0707 15:13:36.017005   353 net.cpp:409] conv2/norm2 -> conv2/norm2
# I0707 15:13:36.017048   353 net.cpp:144] Setting up conv2/norm2
# I0707 15:13:36.017060   353 net.cpp:151] Top shape: 1 192 56 56 (602112)
# I0707 15:13:36.017066   353 net.cpp:159] Memory required for data: 17461248
# I0707 15:13:36.017073   353 layer_factory.hpp:77] Creating layer pool2/3x3_s2
# I0707 15:13:36.017079   353 net.cpp:94] Creating Layer pool2/3x3_s2
# I0707 15:13:36.017088   353 net.cpp:435] pool2/3x3_s2 <- conv2/norm2
# I0707 15:13:36.017096   353 net.cpp:409] pool2/3x3_s2 -> pool2/3x3_s2
# I0707 15:13:36.017133   353 net.cpp:144] Setting up pool2/3x3_s2
# I0707 15:13:36.017145   353 net.cpp:151] Top shape: 1 192 28 28 (150528)
# I0707 15:13:36.017149   353 net.cpp:159] Memory required for data: 18063360
# I0707 15:13:36.017153   353 layer_factory.hpp:77] Creating layer pool2/3x3_s2_pool2/3x3_s2_0_split
# I0707 15:13:36.017165   353 net.cpp:94] Creating Layer pool2/3x3_s2_pool2/3x3_s2_0_split
# I0707 15:13:36.017169   353 net.cpp:435] pool2/3x3_s2_pool2/3x3_s2_0_split <- pool2/3x3_s2
# I0707 15:13:36.017180   353 net.cpp:409] pool2/3x3_s2_pool2/3x3_s2_0_split -> pool2/3x3_s2_pool2/3x3_s2_0_split_0
# I0707 15:13:36.017194   353 net.cpp:409] pool2/3x3_s2_pool2/3x3_s2_0_split -> pool2/3x3_s2_pool2/3x3_s2_0_split_1
# I0707 15:13:36.017204   353 net.cpp:409] pool2/3x3_s2_pool2/3x3_s2_0_split -> pool2/3x3_s2_pool2/3x3_s2_0_split_2
# I0707 15:13:36.017217   353 net.cpp:409] pool2/3x3_s2_pool2/3x3_s2_0_split -> pool2/3x3_s2_pool2/3x3_s2_0_split_3
# I0707 15:13:36.017269   353 net.cpp:144] Setting up pool2/3x3_s2_pool2/3x3_s2_0_split
# I0707 15:13:36.017282   353 net.cpp:151] Top shape: 1 192 28 28 (150528)
# I0707 15:13:36.017288   353 net.cpp:151] Top shape: 1 192 28 28 (150528)
# I0707 15:13:36.017294   353 net.cpp:151] Top shape: 1 192 28 28 (150528)
# I0707 15:13:36.017304   353 net.cpp:151] Top shape: 1 192 28 28 (150528)
# I0707 15:13:36.017308   353 net.cpp:159] Memory required for data: 20471808
# I0707 15:13:36.017318   353 layer_factory.hpp:77] Creating layer inception_3a/1x1
# I0707 15:13:36.017326   353 net.cpp:94] Creating Layer inception_3a/1x1
# I0707 15:13:36.017335   353 net.cpp:435] inception_3a/1x1 <- pool2/3x3_s2_pool2/3x3_s2_0_split_0
# I0707 15:13:36.017344   353 net.cpp:409] inception_3a/1x1 -> inception_3a/1x1
# I0707 15:13:36.018180   353 net.cpp:144] Setting up inception_3a/1x1
# I0707 15:13:36.018203   353 net.cpp:151] Top shape: 1 64 28 28 (50176)
# I0707 15:13:36.018209   353 net.cpp:159] Memory required for data: 20672512
# I0707 15:13:36.018219   353 layer_factory.hpp:77] Creating layer inception_3a/relu_1x1
# I0707 15:13:36.018229   353 net.cpp:94] Creating Layer inception_3a/relu_1x1
# I0707 15:13:36.018239   353 net.cpp:435] inception_3a/relu_1x1 <- inception_3a/1x1
# I0707 15:13:36.018249   353 net.cpp:396] inception_3a/relu_1x1 -> inception_3a/1x1 (in-place)
# I0707 15:13:36.018263   353 net.cpp:144] Setting up inception_3a/relu_1x1
# I0707 15:13:36.018273   353 net.cpp:151] Top shape: 1 64 28 28 (50176)
# I0707 15:13:36.018277   353 net.cpp:159] Memory required for data: 20873216
# I0707 15:13:36.018285   353 layer_factory.hpp:77] Creating layer inception_3a/3x3_reduce
# I0707 15:13:36.018296   353 net.cpp:94] Creating Layer inception_3a/3x3_reduce
# I0707 15:13:36.018306   353 net.cpp:435] inception_3a/3x3_reduce <- pool2/3x3_s2_pool2/3x3_s2_0_split_1
# I0707 15:13:36.018313   353 net.cpp:409] inception_3a/3x3_reduce -> inception_3a/3x3_reduce
# I0707 15:13:36.019222   353 net.cpp:144] Setting up inception_3a/3x3_reduce
# I0707 15:13:36.019246   353 net.cpp:151] Top shape: 1 96 28 28 (75264)
# I0707 15:13:36.019253   353 net.cpp:159] Memory required for data: 21174272
# I0707 15:13:36.019265   353 layer_factory.hpp:77] Creating layer inception_3a/relu_3x3_reduce
# I0707 15:13:36.019279   353 net.cpp:94] Creating Layer inception_3a/relu_3x3_reduce
# I0707 15:13:36.019284   353 net.cpp:435] inception_3a/relu_3x3_reduce <- inception_3a/3x3_reduce
# I0707 15:13:36.019296   353 net.cpp:396] inception_3a/relu_3x3_reduce -> inception_3a/3x3_reduce (in-place)
# I0707 15:13:36.019307   353 net.cpp:144] Setting up inception_3a/relu_3x3_reduce
# I0707 15:13:36.019317   353 net.cpp:151] Top shape: 1 96 28 28 (75264)
# I0707 15:13:36.019321   353 net.cpp:159] Memory required for data: 21475328
# I0707 15:13:36.019330   353 layer_factory.hpp:77] Creating layer inception_3a/3x3
# I0707 15:13:36.019345   353 net.cpp:94] Creating Layer inception_3a/3x3
# I0707 15:13:36.019354   353 net.cpp:435] inception_3a/3x3 <- inception_3a/3x3_reduce
# I0707 15:13:36.019363   353 net.cpp:409] inception_3a/3x3 -> inception_3a/3x3
# I0707 15:13:36.020165   353 net.cpp:144] Setting up inception_3a/3x3
# I0707 15:13:36.020180   353 net.cpp:151] Top shape: 1 128 28 28 (100352)
# I0707 15:13:36.020184   353 net.cpp:159] Memory required for data: 21876736
# I0707 15:13:36.020193   353 layer_factory.hpp:77] Creating layer inception_3a/relu_3x3
# I0707 15:13:36.020206   353 net.cpp:94] Creating Layer inception_3a/relu_3x3
# I0707 15:13:36.020211   353 net.cpp:435] inception_3a/relu_3x3 <- inception_3a/3x3
# I0707 15:13:36.020218   353 net.cpp:396] inception_3a/relu_3x3 -> inception_3a/3x3 (in-place)
# I0707 15:13:36.020227   353 net.cpp:144] Setting up inception_3a/relu_3x3
# I0707 15:13:36.020237   353 net.cpp:151] Top shape: 1 128 28 28 (100352)
# I0707 15:13:36.020241   353 net.cpp:159] Memory required for data: 22278144
# I0707 15:13:36.020251   353 layer_factory.hpp:77] Creating layer inception_3a/5x5_reduce
# I0707 15:13:36.020261   353 net.cpp:94] Creating Layer inception_3a/5x5_reduce
# I0707 15:13:36.020269   353 net.cpp:435] inception_3a/5x5_reduce <- pool2/3x3_s2_pool2/3x3_s2_0_split_2
# I0707 15:13:36.020279   353 net.cpp:409] inception_3a/5x5_reduce -> inception_3a/5x5_reduce
# I0707 15:13:36.020535   353 net.cpp:144] Setting up inception_3a/5x5_reduce
# I0707 15:13:36.020551   353 net.cpp:151] Top shape: 1 16 28 28 (12544)
# I0707 15:13:36.020556   353 net.cpp:159] Memory required for data: 22328320
# I0707 15:13:36.020566   353 layer_factory.hpp:77] Creating layer inception_3a/relu_5x5_reduce
# I0707 15:13:36.020575   353 net.cpp:94] Creating Layer inception_3a/relu_5x5_reduce
# I0707 15:13:36.020584   353 net.cpp:435] inception_3a/relu_5x5_reduce <- inception_3a/5x5_reduce
# I0707 15:13:36.020593   353 net.cpp:396] inception_3a/relu_5x5_reduce -> inception_3a/5x5_reduce (in-place)
# I0707 15:13:36.020606   353 net.cpp:144] Setting up inception_3a/relu_5x5_reduce
# I0707 15:13:36.020617   353 net.cpp:151] Top shape: 1 16 28 28 (12544)
# I0707 15:13:36.020620   353 net.cpp:159] Memory required for data: 22378496
# I0707 15:13:36.020628   353 layer_factory.hpp:77] Creating layer inception_3a/5x5
# I0707 15:13:36.020638   353 net.cpp:94] Creating Layer inception_3a/5x5
# I0707 15:13:36.020648   353 net.cpp:435] inception_3a/5x5 <- inception_3a/5x5_reduce
# I0707 15:13:36.020658   353 net.cpp:409] inception_3a/5x5 -> inception_3a/5x5
# I0707 15:13:36.020942   353 net.cpp:144] Setting up inception_3a/5x5
# I0707 15:13:36.020957   353 net.cpp:151] Top shape: 1 32 28 28 (25088)
# I0707 15:13:36.020961   353 net.cpp:159] Memory required for data: 22478848
# I0707 15:13:36.020967   353 layer_factory.hpp:77] Creating layer inception_3a/relu_5x5
# I0707 15:13:36.020975   353 net.cpp:94] Creating Layer inception_3a/relu_5x5
# I0707 15:13:36.020982   353 net.cpp:435] inception_3a/relu_5x5 <- inception_3a/5x5
# I0707 15:13:36.020992   353 net.cpp:396] inception_3a/relu_5x5 -> inception_3a/5x5 (in-place)
# I0707 15:13:36.021005   353 net.cpp:144] Setting up inception_3a/relu_5x5
# I0707 15:13:36.021013   353 net.cpp:151] Top shape: 1 32 28 28 (25088)
# I0707 15:13:36.021021   353 net.cpp:159] Memory required for data: 22579200
# I0707 15:13:36.021025   353 layer_factory.hpp:77] Creating layer inception_3a/pool
# I0707 15:13:36.021034   353 net.cpp:94] Creating Layer inception_3a/pool
# I0707 15:13:36.021042   353 net.cpp:435] inception_3a/pool <- pool2/3x3_s2_pool2/3x3_s2_0_split_3
# I0707 15:13:36.021051   353 net.cpp:409] inception_3a/pool -> inception_3a/pool
# I0707 15:13:36.021092   353 net.cpp:144] Setting up inception_3a/pool
# I0707 15:13:36.021106   353 net.cpp:151] Top shape: 1 192 28 28 (150528)
# I0707 15:13:36.021116   353 net.cpp:159] Memory required for data: 23181312
# I0707 15:13:36.021119   353 layer_factory.hpp:77] Creating layer inception_3a/pool_proj
# I0707 15:13:36.021131   353 net.cpp:94] Creating Layer inception_3a/pool_proj
# I0707 15:13:36.021140   353 net.cpp:435] inception_3a/pool_proj <- inception_3a/pool
# I0707 15:13:36.021147   353 net.cpp:409] inception_3a/pool_proj -> inception_3a/pool_proj
# I0707 15:13:36.021381   353 net.cpp:144] Setting up inception_3a/pool_proj
# I0707 15:13:36.021395   353 net.cpp:151] Top shape: 1 32 28 28 (25088)
# I0707 15:13:36.021399   353 net.cpp:159] Memory required for data: 23281664
# I0707 15:13:36.021416   353 layer_factory.hpp:77] Creating layer inception_3a/relu_pool_proj
# I0707 15:13:36.021427   353 net.cpp:94] Creating Layer inception_3a/relu_pool_proj
# I0707 15:13:36.021437   353 net.cpp:435] inception_3a/relu_pool_proj <- inception_3a/pool_proj
# I0707 15:13:36.021450   353 net.cpp:396] inception_3a/relu_pool_proj -> inception_3a/pool_proj (in-place)
# I0707 15:13:36.021464   353 net.cpp:144] Setting up inception_3a/relu_pool_proj
# I0707 15:13:36.021474   353 net.cpp:151] Top shape: 1 32 28 28 (25088)
# I0707 15:13:36.021478   353 net.cpp:159] Memory required for data: 23382016
# I0707 15:13:36.021482   353 layer_factory.hpp:77] Creating layer inception_3a/output
# I0707 15:13:36.021490   353 net.cpp:94] Creating Layer inception_3a/output
# I0707 15:13:36.021495   353 net.cpp:435] inception_3a/output <- inception_3a/1x1
# I0707 15:13:36.021500   353 net.cpp:435] inception_3a/output <- inception_3a/3x3
# I0707 15:13:36.021512   353 net.cpp:435] inception_3a/output <- inception_3a/5x5
# I0707 15:13:36.021517   353 net.cpp:435] inception_3a/output <- inception_3a/pool_proj
# I0707 15:13:36.021525   353 net.cpp:409] inception_3a/output -> inception_3a/output
# I0707 15:13:36.021559   353 net.cpp:144] Setting up inception_3a/output
# I0707 15:13:36.021571   353 net.cpp:151] Top shape: 1 256 28 28 (200704)
# I0707 15:13:36.021581   353 net.cpp:159] Memory required for data: 24184832
# I0707 15:13:36.021589   353 layer_factory.hpp:77] Creating layer inception_3a/output_inception_3a/output_0_split
# I0707 15:13:36.021603   353 net.cpp:94] Creating Layer inception_3a/output_inception_3a/output_0_split
# I0707 15:13:36.021612   353 net.cpp:435] inception_3a/output_inception_3a/output_0_split <- inception_3a/output
# I0707 15:13:36.021626   353 net.cpp:409] inception_3a/output_inception_3a/output_0_split -> inception_3a/output_inception_3a/output_0_split_0
# I0707 15:13:36.021639   353 net.cpp:409] inception_3a/output_inception_3a/output_0_split -> inception_3a/output_inception_3a/output_0_split_1
# I0707 15:13:36.021651   353 net.cpp:409] inception_3a/output_inception_3a/output_0_split -> inception_3a/output_inception_3a/output_0_split_2
# I0707 15:13:36.021663   353 net.cpp:409] inception_3a/output_inception_3a/output_0_split -> inception_3a/output_inception_3a/output_0_split_3
# I0707 15:13:36.021721   353 net.cpp:144] Setting up inception_3a/output_inception_3a/output_0_split
# I0707 15:13:36.021733   353 net.cpp:151] Top shape: 1 256 28 28 (200704)
# I0707 15:13:36.021739   353 net.cpp:151] Top shape: 1 256 28 28 (200704)
# I0707 15:13:36.021744   353 net.cpp:151] Top shape: 1 256 28 28 (200704)
# I0707 15:13:36.021754   353 net.cpp:151] Top shape: 1 256 28 28 (200704)
# I0707 15:13:36.021759   353 net.cpp:159] Memory required for data: 27396096
# I0707 15:13:36.021762   353 layer_factory.hpp:77] Creating layer inception_3b/1x1
# I0707 15:13:36.021773   353 net.cpp:94] Creating Layer inception_3b/1x1
# I0707 15:13:36.021783   353 net.cpp:435] inception_3b/1x1 <- inception_3a/output_inception_3a/output_0_split_0
# I0707 15:13:36.021792   353 net.cpp:409] inception_3b/1x1 -> inception_3b/1x1
# I0707 15:13:36.022171   353 net.cpp:144] Setting up inception_3b/1x1
# I0707 15:13:36.022186   353 net.cpp:151] Top shape: 1 128 28 28 (100352)
# I0707 15:13:36.022192   353 net.cpp:159] Memory required for data: 27797504
# I0707 15:13:36.022204   353 layer_factory.hpp:77] Creating layer inception_3b/relu_1x1
# I0707 15:13:36.022217   353 net.cpp:94] Creating Layer inception_3b/relu_1x1
# I0707 15:13:36.022228   353 net.cpp:435] inception_3b/relu_1x1 <- inception_3b/1x1
# I0707 15:13:36.022238   353 net.cpp:396] inception_3b/relu_1x1 -> inception_3b/1x1 (in-place)
# I0707 15:13:36.022250   353 net.cpp:144] Setting up inception_3b/relu_1x1
# I0707 15:13:36.022261   353 net.cpp:151] Top shape: 1 128 28 28 (100352)
# I0707 15:13:36.022265   353 net.cpp:159] Memory required for data: 28198912
# I0707 15:13:36.022274   353 layer_factory.hpp:77] Creating layer inception_3b/3x3_reduce
# ...
# I0707 15:13:36.090171   353 net.cpp:222] inception_5b/relu_5x5 does not need backward computation.
# I0707 15:13:36.090181   353 net.cpp:222] inception_5b/5x5 does not need backward computation.
# I0707 15:13:36.090185   353 net.cpp:222] inception_5b/relu_5x5_reduce does not need backward computation.
# I0707 15:13:36.090191   353 net.cpp:222] inception_5b/5x5_reduce does not need backward computation.
# I0707 15:13:36.090195   353 net.cpp:222] inception_5b/relu_3x3 does not need backward computation.
# I0707 15:13:36.090201   353 net.cpp:222] inception_5b/3x3 does not need backward computation.
# I0707 15:13:36.090205   353 net.cpp:222] inception_5b/relu_3x3_reduce does not need backward computation.
# I0707 15:13:36.090209   353 net.cpp:222] inception_5b/3x3_reduce does not need backward computation.
# I0707 15:13:36.090215   353 net.cpp:222] inception_5b/relu_1x1 does not need backward computation.
# I0707 15:13:36.090220   353 net.cpp:222] inception_5b/1x1 does not need backward computation.
# I0707 15:13:36.090225   353 net.cpp:222] inception_5a/output_inception_5a/output_0_split does not need backward computation.
# I0707 15:13:36.090232   353 net.cpp:222] inception_5a/output does not need backward computation.
# I0707 15:13:36.090237   353 net.cpp:222] inception_5a/relu_pool_proj does not need backward computation.
# I0707 15:13:36.090243   353 net.cpp:222] inception_5a/pool_proj does not need backward computation.
# I0707 15:13:36.090253   353 net.cpp:222] inception_5a/pool does not need backward computation.
# I0707 15:13:36.090262   353 net.cpp:222] inception_5a/relu_5x5 does not need backward computation.
# I0707 15:13:36.090271   353 net.cpp:222] inception_5a/5x5 does not need backward computation.
# I0707 15:13:36.090277   353 net.cpp:222] inception_5a/relu_5x5_reduce does not need backward computation.
# I0707 15:13:36.090283   353 net.cpp:222] inception_5a/5x5_reduce does not need backward computation.
# I0707 15:13:36.090288   353 net.cpp:222] inception_5a/relu_3x3 does not need backward computation.
# I0707 15:13:36.090296   353 net.cpp:222] inception_5a/3x3 does not need backward computation.
# I0707 15:13:36.090301   353 net.cpp:222] inception_5a/relu_3x3_reduce does not need backward computation.
# I0707 15:13:36.090306   353 net.cpp:222] inception_5a/3x3_reduce does not need backward computation.
# I0707 15:13:36.090312   353 net.cpp:222] inception_5a/relu_1x1 does not need backward computation.
# I0707 15:13:36.090317   353 net.cpp:222] inception_5a/1x1 does not need backward computation.
# I0707 15:13:36.090324   353 net.cpp:222] pool4/3x3_s2_pool4/3x3_s2_0_split does not need backward computation.
# I0707 15:13:36.090330   353 net.cpp:222] pool4/3x3_s2 does not need backward computation.
# I0707 15:13:36.090337   353 net.cpp:222] inception_4e/output does not need backward computation.
# I0707 15:13:36.090342   353 net.cpp:222] inception_4e/relu_pool_proj does not need backward computation.
# I0707 15:13:36.090348   353 net.cpp:222] inception_4e/pool_proj does not need backward computation.
# I0707 15:13:36.090354   353 net.cpp:222] inception_4e/pool does not need backward computation.
# I0707 15:13:36.090360   353 net.cpp:222] inception_4e/relu_5x5 does not need backward computation.
# I0707 15:13:36.090366   353 net.cpp:222] inception_4e/5x5 does not need backward computation.
# I0707 15:13:36.090374   353 net.cpp:222] inception_4e/relu_5x5_reduce does not need backward computation.
# I0707 15:13:36.090384   353 net.cpp:222] inception_4e/5x5_reduce does not need backward computation.
# I0707 15:13:36.090389   353 net.cpp:222] inception_4e/relu_3x3 does not need backward computation.
# I0707 15:13:36.090396   353 net.cpp:222] inception_4e/3x3 does not need backward computation.
# I0707 15:13:36.090401   353 net.cpp:222] inception_4e/relu_3x3_reduce does not need backward computation.
# I0707 15:13:36.090410   353 net.cpp:222] inception_4e/3x3_reduce does not need backward computation.
# I0707 15:13:36.090415   353 net.cpp:222] inception_4e/relu_1x1 does not need backward computation.
# I0707 15:13:36.090425   353 net.cpp:222] inception_4e/1x1 does not need backward computation.
# I0707 15:13:36.090430   353 net.cpp:222] inception_4d/output_inception_4d/output_0_split does not need backward computation.
# I0707 15:13:36.090438   353 net.cpp:222] inception_4d/output does not need backward computation.
# I0707 15:13:36.090445   353 net.cpp:222] inception_4d/relu_pool_proj does not need backward computation.
# I0707 15:13:36.090453   353 net.cpp:222] inception_4d/pool_proj does not need backward computation.
# I0707 15:13:36.090458   353 net.cpp:222] inception_4d/pool does not need backward computation.
# I0707 15:13:36.090466   353 net.cpp:222] inception_4d/relu_5x5 does not need backward computation.
# I0707 15:13:36.090469   353 net.cpp:222] inception_4d/5x5 does not need backward computation.
# I0707 15:13:36.090476   353 net.cpp:222] inception_4d/relu_5x5_reduce does not need backward computation.
# I0707 15:13:36.090479   353 net.cpp:222] inception_4d/5x5_reduce does not need backward computation.
# I0707 15:13:36.090488   353 net.cpp:222] inception_4d/relu_3x3 does not need backward computation.
# I0707 15:13:36.090492   353 net.cpp:222] inception_4d/3x3 does not need backward computation.
# I0707 15:13:36.090498   353 net.cpp:222] inception_4d/relu_3x3_reduce does not need backward computation.
# I0707 15:13:36.090503   353 net.cpp:222] inception_4d/3x3_reduce does not need backward computation.
# I0707 15:13:36.090508   353 net.cpp:222] inception_4d/relu_1x1 does not need backward computation.
# I0707 15:13:36.090513   353 net.cpp:222] inception_4d/1x1 does not need backward computation.
# I0707 15:13:36.090519   353 net.cpp:222] inception_4c/output_inception_4c/output_0_split does not need backward computation.
# I0707 15:13:36.090528   353 net.cpp:222] inception_4c/output does not need backward computation.
# I0707 15:13:36.090533   353 net.cpp:222] inception_4c/relu_pool_proj does not need backward computation.
# I0707 15:13:36.090539   353 net.cpp:222] inception_4c/pool_proj does not need backward computation.
# I0707 15:13:36.090545   353 net.cpp:222] inception_4c/pool does not need backward computation.
# I0707 15:13:36.090553   353 net.cpp:222] inception_4c/relu_5x5 does not need backward computation.
# I0707 15:13:36.090557   353 net.cpp:222] inception_4c/5x5 does not need backward computation.
# I0707 15:13:36.090564   353 net.cpp:222] inception_4c/relu_5x5_reduce does not need backward computation.
# I0707 15:13:36.090569   353 net.cpp:222] inception_4c/5x5_reduce does not need backward computation.
# I0707 15:13:36.090575   353 net.cpp:222] inception_4c/relu_3x3 does not need backward computation.
# I0707 15:13:36.090584   353 net.cpp:222] inception_4c/3x3 does not need backward computation.
# I0707 15:13:36.090593   353 net.cpp:222] inception_4c/relu_3x3_reduce does not need backward computation.
# I0707 15:13:36.090602   353 net.cpp:222] inception_4c/3x3_reduce does not need backward computation.
# I0707 15:13:36.090612   353 net.cpp:222] inception_4c/relu_1x1 does not need backward computation.
# I0707 15:13:36.090621   353 net.cpp:222] inception_4c/1x1 does not need backward computation.
# I0707 15:13:36.090631   353 net.cpp:222] inception_4b/output_inception_4b/output_0_split does not need backward computation.
# I0707 15:13:36.090641   353 net.cpp:222] inception_4b/output does not need backward computation.
# I0707 15:13:36.090653   353 net.cpp:222] inception_4b/relu_pool_proj does not need backward computation.
# I0707 15:13:36.090662   353 net.cpp:222] inception_4b/pool_proj does not need backward computation.
# I0707 15:13:36.090670   353 net.cpp:222] inception_4b/pool does not need backward computation.
# I0707 15:13:36.090679   353 net.cpp:222] inception_4b/relu_5x5 does not need backward computation.
# I0707 15:13:36.090688   353 net.cpp:222] inception_4b/5x5 does not need backward computation.
# I0707 15:13:36.090693   353 net.cpp:222] inception_4b/relu_5x5_reduce does not need backward computation.
# I0707 15:13:36.090701   353 net.cpp:222] inception_4b/5x5_reduce does not need backward computation.
# I0707 15:13:36.090710   353 net.cpp:222] inception_4b/relu_3x3 does not need backward computation.
# I0707 15:13:36.090720   353 net.cpp:222] inception_4b/3x3 does not need backward computation.
# I0707 15:13:36.090724   353 net.cpp:222] inception_4b/relu_3x3_reduce does not need backward computation.
# I0707 15:13:36.090728   353 net.cpp:222] inception_4b/3x3_reduce does not need backward computation.
# I0707 15:13:36.090734   353 net.cpp:222] inception_4b/relu_1x1 does not need backward computation.
# I0707 15:13:36.090744   353 net.cpp:222] inception_4b/1x1 does not need backward computation.
# I0707 15:13:36.090749   353 net.cpp:222] inception_4a/output_inception_4a/output_0_split does not need backward computation.
# I0707 15:13:36.090755   353 net.cpp:222] inception_4a/output does not need backward computation.
# I0707 15:13:36.090766   353 net.cpp:222] inception_4a/relu_pool_proj does not need backward computation.
# I0707 15:13:36.090771   353 net.cpp:222] inception_4a/pool_proj does not need backward computation.
# I0707 15:13:36.090780   353 net.cpp:222] inception_4a/pool does not need backward computation.
# I0707 15:13:36.090785   353 net.cpp:222] inception_4a/relu_5x5 does not need backward computation.
# I0707 15:13:36.090788   353 net.cpp:222] inception_4a/5x5 does not need backward computation.
# I0707 15:13:36.090793   353 net.cpp:222] inception_4a/relu_5x5_reduce does not need backward computation.
# I0707 15:13:36.090797   353 net.cpp:222] inception_4a/5x5_reduce does not need backward computation.
# I0707 15:13:36.090806   353 net.cpp:222] inception_4a/relu_3x3 does not need backward computation.
# I0707 15:13:36.090811   353 net.cpp:222] inception_4a/3x3 does not need backward computation.
# I0707 15:13:36.090819   353 net.cpp:222] inception_4a/relu_3x3_reduce does not need backward computation.
# I0707 15:13:36.090827   353 net.cpp:222] inception_4a/3x3_reduce does not need backward computation.
# I0707 15:13:36.090832   353 net.cpp:222] inception_4a/relu_1x1 does not need backward computation.
# I0707 15:13:36.090840   353 net.cpp:222] inception_4a/1x1 does not need backward computation.
# I0707 15:13:36.090850   353 net.cpp:222] pool3/3x3_s2_pool3/3x3_s2_0_split does not need backward computation.
# I0707 15:13:36.090860   353 net.cpp:222] pool3/3x3_s2 does not need backward computation.
# I0707 15:13:36.090869   353 net.cpp:222] inception_3b/output does not need backward computation.
# I0707 15:13:36.090880   353 net.cpp:222] inception_3b/relu_pool_proj does not need backward computation.
# I0707 15:13:36.090888   353 net.cpp:222] inception_3b/pool_proj does not need backward computation.
# I0707 15:13:36.090898   353 net.cpp:222] inception_3b/pool does not need backward computation.
# I0707 15:13:36.090907   353 net.cpp:222] inception_3b/relu_5x5 does not need backward computation.
# I0707 15:13:36.090915   353 net.cpp:222] inception_3b/5x5 does not need backward computation.
# I0707 15:13:36.090924   353 net.cpp:222] inception_3b/relu_5x5_reduce does not need backward computation.
# I0707 15:13:36.090934   353 net.cpp:222] inception_3b/5x5_reduce does not need backward computation.
# I0707 15:13:36.090942   353 net.cpp:222] inception_3b/relu_3x3 does not need backward computation.
# I0707 15:13:36.090950   353 net.cpp:222] inception_3b/3x3 does not need backward computation.
# I0707 15:13:36.090960   353 net.cpp:222] inception_3b/relu_3x3_reduce does not need backward computation.
# I0707 15:13:36.090968   353 net.cpp:222] inception_3b/3x3_reduce does not need backward computation.
# I0707 15:13:36.090977   353 net.cpp:222] inception_3b/relu_1x1 does not need backward computation.
# I0707 15:13:36.090986   353 net.cpp:222] inception_3b/1x1 does not need backward computation.
# I0707 15:13:36.090996   353 net.cpp:222] inception_3a/output_inception_3a/output_0_split does not need backward computation.
# I0707 15:13:36.091004   353 net.cpp:222] inception_3a/output does not need backward computation.
# I0707 15:13:36.091013   353 net.cpp:222] inception_3a/relu_pool_proj does not need backward computation.
# I0707 15:13:36.091022   353 net.cpp:222] inception_3a/pool_proj does not need backward computation.
# I0707 15:13:36.091027   353 net.cpp:222] inception_3a/pool does not need backward computation.
# I0707 15:13:36.091037   353 net.cpp:222] inception_3a/relu_5x5 does not need backward computation.
# I0707 15:13:36.091040   353 net.cpp:222] inception_3a/5x5 does not need backward computation.
# I0707 15:13:36.091050   353 net.cpp:222] inception_3a/relu_5x5_reduce does not need backward computation.
# I0707 15:13:36.091054   353 net.cpp:222] inception_3a/5x5_reduce does not need backward computation.
# I0707 15:13:36.091064   353 net.cpp:222] inception_3a/relu_3x3 does not need backward computation.
# I0707 15:13:36.091068   353 net.cpp:222] inception_3a/3x3 does not need backward computation.
# I0707 15:13:36.091073   353 net.cpp:222] inception_3a/relu_3x3_reduce does not need backward computation.
# I0707 15:13:36.091078   353 net.cpp:222] inception_3a/3x3_reduce does not need backward computation.
# I0707 15:13:36.091087   353 net.cpp:222] inception_3a/relu_1x1 does not need backward computation.
# I0707 15:13:36.091095   353 net.cpp:222] inception_3a/1x1 does not need backward computation.
# I0707 15:13:36.091105   353 net.cpp:222] pool2/3x3_s2_pool2/3x3_s2_0_split does not need backward computation.
# I0707 15:13:36.091114   353 net.cpp:222] pool2/3x3_s2 does not need backward computation.
# I0707 15:13:36.091123   353 net.cpp:222] conv2/norm2 does not need backward computation.
# I0707 15:13:36.091132   353 net.cpp:222] conv2/relu_3x3 does not need backward computation.
# I0707 15:13:36.091141   353 net.cpp:222] conv2/3x3 does not need backward computation.
# I0707 15:13:36.091150   353 net.cpp:222] conv2/relu_3x3_reduce does not need backward computation.
# I0707 15:13:36.091159   353 net.cpp:222] conv2/3x3_reduce does not need backward computation.
# I0707 15:13:36.091168   353 net.cpp:222] pool1/norm1 does not need backward computation.
# I0707 15:13:36.091176   353 net.cpp:222] pool1/3x3_s2 does not need backward computation.
# I0707 15:13:36.091188   353 net.cpp:222] conv1/relu_7x7 does not need backward computation.
# I0707 15:13:36.091197   353 net.cpp:222] conv1/7x7_s2 does not need backward computation.
# I0707 15:13:36.091205   353 net.cpp:222] input does not need backward computation.
# I0707 15:13:36.091213   353 net.cpp:264] This network produces output softmax
# I0707 15:13:36.091329   353 net.cpp:284] Network initialization done.
# I0707 15:13:36.118417   353 net.cpp:791] Ignoring source layer train-data
# I0707 15:13:36.118450   353 net.cpp:791] Ignoring source layer label_train-data_1_split
# I0707 15:13:36.119395   353 net.cpp:791] Ignoring source layer loss1/ave_pool
# I0707 15:13:36.119410   353 net.cpp:791] Ignoring source layer loss1/conv
# I0707 15:13:36.119413   353 net.cpp:791] Ignoring source layer loss1/relu_conv
# I0707 15:13:36.119417   353 net.cpp:791] Ignoring source layer loss1/fc
# I0707 15:13:36.119423   353 net.cpp:791] Ignoring source layer loss1/relu_fc
# I0707 15:13:36.119431   353 net.cpp:791] Ignoring source layer loss1/drop_fc
# I0707 15:13:36.119441   353 net.cpp:791] Ignoring source layer loss1/classifier
# I0707 15:13:36.119444   353 net.cpp:791] Ignoring source layer loss1/loss
# I0707 15:13:36.120829   353 net.cpp:791] Ignoring source layer loss2/ave_pool
# I0707 15:13:36.120843   353 net.cpp:791] Ignoring source layer loss2/conv
# I0707 15:13:36.120847   353 net.cpp:791] Ignoring source layer loss2/relu_conv
# I0707 15:13:36.120851   353 net.cpp:791] Ignoring source layer loss2/fc
# I0707 15:13:36.120860   353 net.cpp:791] Ignoring source layer loss2/relu_fc
# I0707 15:13:36.120865   353 net.cpp:791] Ignoring source layer loss2/drop_fc
# I0707 15:13:36.120873   353 net.cpp:791] Ignoring source layer loss2/classifier
# I0707 15:13:36.120877   353 net.cpp:791] Ignoring source layer loss2/loss
# I0707 15:13:36.123808   353 net.cpp:791] Ignoring source layer loss3/loss
# not whale

# %%
# !ls /dli/data/digits/20180707-144124-9747
# Out:
# create_train_db.log  labels.txt        mean.jpg       train.txt  val.txt
# create_val_db.log    mean.binaryproto  status.pickle  train_db	 val_db

# %%
# !ls /dli/data/digits/20180707-145226-135e
# Out:
# caffe_output.log   snapshot_iter_256.caffemodel   status.pickle
# deploy.prototxt    snapshot_iter_256.solverstate  train_val.prototxt
# original.prototxt  solver.prototxt

# %%
# !ls /dli/data/digits/20180707-144641-812f
# Out:
# create_train_db.log  labels.txt        mean.jpg       train.txt  val.txt
# create_val_db.log    mean.binaryproto  status.pickle  train_db	 val_db
